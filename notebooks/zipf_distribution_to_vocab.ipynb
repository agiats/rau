# %%
import argparse
import os
import random


class PCFG:
    """
    PCFG to sample sentences from
    """
    def __init__(self, grammar_file):
        self.rules = None
        self.change_rules = None
        self.load_rules(grammar_file)

    def load_rules(self, grammar_file):
        new_rules = {}
        change = {}
        g_file = open(grammar_file, 'r')
        lines = g_file.readlines()
        for l in lines:
            if l.startswith(('#', " ", "\t", "\n")) or len(l) < 1:
                continue
            else:
                if l.find("#") != -1:
                    l = l[:l.find("#")]
                idx = -1
                if len(l.rstrip().split("\t")) == 3:
                    weight, lhs, rhs = l.rstrip().split("\t")
                elif len(l.rstrip().split("\t")) == 4:
                    weight, lhs, rhs, idx = l.rstrip().split("\t")
                if lhs not in new_rules.keys():
                    new_rules[lhs] = []
                poss_rhs = new_rules[lhs]
                poss_rhs.append([rhs, float(weight)])
                if idx != -1:
                    change[lhs + "\t" + rhs] = idx
        for lhs, poss in new_rules.items():
            total = 0
            for rhs in poss:
                print(rhs[1])
                total += rhs[1]
            for rhs in poss:
                rhs[1] /= total
        self.rules = new_rules
        self.change_rules = change

    def sample_sentence(self, max_expansions, bracketing):
        self.expansions = 0
        done = False
        sent = ["ROOT"]
        idx = 0
        while not done:
            if sent[idx] not in self.rules.keys():
                idx += 1
                if idx >= len(sent):
                    done = True
                continue
            else:
                replace, change_idx = self.expand(sent[idx])
                if bracketing:
                    if change_idx == -1:
                        sent = (sent[:idx]
                            + ["(", sent[idx]] + replace + [")"]
                            + sent[idx + 1:])
                    else:
                        sent = (sent[:idx]
                            + ["(", change_idx + sent[idx]] + replace + [")"]
                            + sent[idx + 1:])
                else:
                    sent = sent[:idx] + replace  + sent[idx + 1:]
                self.expansions += 1
                if bracketing:
                    idx += 2
                if self.expansions > max_expansions:
                    done = True
                if idx >= len(sent):
                    done = True
        if self.expansions > max_expansions:
            for idx in range(len(sent)):
                if not bracketing:
                    if sent[idx] in self.rules.keys():
                        sent[idx] = "..."
                else:
                    if sent[idx] in self.rules.keys() and sent[idx - 1] != "(":
                        sent[idx] = "..."
        return ' '.join(sent)

    def expand(self, symbol):
        poss = self.rules[symbol]
        sample = random.random()
        val = 0.0
        rhs = ""
        idx = -1
        for p in poss:
            val += p[1]
            if sample <= val:
                if symbol + "\t" + p[0] in self.change_rules.keys():
                    idx = self.change_rules[symbol + "\t" + p[0]]
                rhs = p[0]
                break
        return rhs.split(" "), idx

# %% [markdown]
# ## Assign Zip weights

# %%
def update_grammar_with_zipf_weights(grammar_file, output_file=None):
    def is_terminal(symbol):
        return not symbol[0].isupper() or symbol == '[eos]'

    def is_nonterminal(symbol):
        return symbol[0].isupper()

    # 終端記号への遷移ルールを左辺ごとにグループ化
    terminal_rules_by_lhs = {}

    # ファイルを読んで終端記号ルールを特定
    with open(grammar_file, 'r') as f:
        lines = f.readlines()

    for line in lines:
        if line.startswith(('#', " ", "\t", "\n")) or len(line) < 1:
            continue
        if line.find("#") != -1:
            line = line[:line.find("#")]

        parts = line.strip().split("\t")
        if len(parts) >= 3:
            lhs, rhs = parts[1], parts[2]
            # Nonterminal -> Terminal ルールを特定
            # 右辺が単一の要素であることを確認
            if is_nonterminal(lhs) and ' ' not in rhs and is_terminal(rhs):
                if lhs not in terminal_rules_by_lhs:
                    terminal_rules_by_lhs[lhs] = []
                terminal_rules_by_lhs[lhs].append((parts[0], rhs, parts[3:] if len(parts) > 3 else []))

    # 新しいweightを割り当てて書き戻す
    new_lines = []
    for line in lines:
        if line.startswith(('#', " ", "\t", "\n")) or len(line) < 1:
            new_lines.append(line)
            continue

        if line.find("#") != -1:
            line = line[:line.find("#")]

        parts = line.strip().split("\t")
        if len(parts) >= 3:
            lhs, rhs = parts[1], parts[2]

            if is_nonterminal(lhs) and ' ' not in rhs and is_terminal(rhs) and lhs in terminal_rules_by_lhs:
                # Nonterminal -> Terminal ルールの場合、ランクを重みとして設定
                rules = terminal_rules_by_lhs[lhs]
                rank = rules.index((parts[0], rhs, parts[3:] if len(parts) > 3 else [])) + 1
                new_line = f"{rank}\t{lhs}\t{rhs}"
                if len(parts) > 3:
                    new_line += '\t' + '\t'.join(parts[3:])
                new_lines.append(new_line + '\n')
            else:
                # それ以外のルールの場合はそのまま
                new_lines.append(line)

    # ファイルに書き戻す
    if output_file:
        with open(output_file, 'w') as f:
            f.writelines(new_lines)
    return new_lines

# %%
base_grammar_path = "/home/agiats/Projects/impossible_inherent_entropy/data_gen/base-grammar_eos.gr"
zipf_grammar_path = "/home/agiats/Projects/impossible_inherent_entropy/data_gen/base-grammar_eos_zipf.gr"
print(''.join(update_grammar_with_zipf_weights(base_grammar_path)))
# Out:
# 1	ROOT	S
# 1	S	NP_Subj_S VP_S EOS	1
# 1	S	NP_Subj_P VP_P EOS	1
# 1	S'	NP_Subj_S VP_S	1
# 1	S'	NP_Subj_P VP_P	1
# 1	VP_S	VP_Past_S
# 1	VP_S	VP_Pres_S
# 1	VP_S	VP_Comp_S
# 1	VP_P	VP_Past_P
# 1	VP_P	VP_Pres_P
# 1	VP_P	VP_Comp_P
# 1	VP_Comp_S	VP_Comp_Pres_S
# 1	VP_Comp_S	VP_Comp_Past_S
# 1	VP_Comp_P	VP_Comp_Pres_P
# 1	VP_Comp_P	VP_Comp_Past_P
# 1	NP_Subj_S	NP_S Subj
# 1	NP_Subj_P	NP_P Subj
# 1	VP_Past_S	IVerb_Past_S
# 1	VP_Pres_S	IVerb_Pres_S
# 1	VP_Past_P	IVerb_Past_P
# 1	VP_Pres_P	IVerb_Pres_P
# 1	VP_Past_S	NP_Obj TVerb_Past_S	2
# 1	VP_Pres_S	NP_Obj TVerb_Pres_S	2
# 1	VP_Comp_Pres_S	S_Comp Verb_Comp_Pres_S	2
# 1	VP_Comp_Past_S	S_Comp Verb_Comp_Past_S	2
# 1	VP_Past_P	NP_Obj TVerb_Past_P	2
# 1	VP_Pres_P	NP_Obj TVerb_Pres_P	2
# 1	VP_Comp_Pres_P	S_Comp Verb_Comp_Pres_P	2
# 1	VP_Comp_Past_P	S_Comp Verb_Comp_Past_P	2
# 1	S_Comp	S' Comp	3
# 1	NP_Obj	NP_S Obj
# 1	NP_Obj	NP_P Obj
# 1	NP_S	Noun_S
# 1	NP_P	Noun_P
# 0.2	NP_S	PP NP_S	4
# 0.2	NP_P	PP NP_P	4
# 1	PP	NP_S Prep	4
# 1	PP	NP_P Prep	4
# 1	NP_S	Adj Noun_S	5
# 1	NP_P	Adj Noun_P	5
# 1	Adj	Adj CC Adj
# 1	NP_S	VP_S Rel Noun_S	6
# 1	NP_P	VP_P Rel Noun_P	6
# 0.025	NP_P	NP_S CC NP_S
# 0.025	NP_P	NP_P CC NP_P
# 0.025	NP_P	NP_P CC NP_S
# 0.025	NP_P	NP_S CC NP_P
# 0.2	TVerb_Past_S	TVerb_Past_S CC TVerb_Past_S
# 0.2	TVerb_Pres_S	TVerb_Pres_S CC TVerb_Pres_S
# 0.2	IVerb_Past_S	IVerb_Past_S CC IVerb_Past_S
# 0.2	IVerb_Pres_S	IVerb_Pres_S CC IVerb_Pres_S
# 0.2	TVerb_Past_P	TVerb_Past_P CC TVerb_Past_P
# 0.2	TVerb_Pres_P	TVerb_Pres_P CC TVerb_Pres_P
# 0.2	IVerb_Past_P	IVerb_Past_P CC IVerb_Past_P
# 0.2	IVerb_Pres_P	IVerb_Pres_P CC IVerb_Pres_P
# 1	NP_S	Pronoun_S
# 1	NP_P	Pronoun_P
# 1	Noun_S	amackist
# 2	Noun_S	amationist
# 3	Noun_S	ambather
# 4	Noun_S	ampercial
# 5	Noun_S	appalate
# 6	Noun_S	autoner
# 7	Noun_S	bactivitor
# 8	Noun_S	ballison
# 9	Noun_S	banitician
# 10	Noun_S	bellion
# 11	Noun_S	benatician
# 12	Noun_S	bleckman
# 13	Noun_S	blope
# 14	Noun_S	bolicater
# 15	Noun_S	bolician
# 16	Noun_S	bolitist
# 17	Noun_S	botigner
# 18	Noun_S	bottist
# 19	Noun_S	breaper
# 20	Noun_S	brelland
# 21	Noun_S	briticist
# 21	Noun_S	briticist
# 23	Noun_S	buestor
# 24	Noun_S	bullager
# 25	Noun_S	bullawer
# 26	Noun_S	bullif
# 27	Noun_S	bullifist
# 28	Noun_S	bunessator
# 29	Noun_S	burse
# 30	Noun_S	businator
# 31	Noun_S	businer
# 32	Noun_S	calinelist
# 33	Noun_S	cheldor
# 34	Noun_S	crotician
# 35	Noun_S	crotifer
# 36	Noun_S	cushar
# 37	Noun_S	dake
# 38	Noun_S	dargine
# 39	Noun_S	denatician
# 40	Noun_S	doloner
# 41	Noun_S	dolonician
# 42	Noun_S	dorpal
# 43	Noun_S	dorpalist
# 44	Noun_S	draccont
# 45	Noun_S	drinimat
# 46	Noun_S	droinist
# 47	Noun_S	drouseman
# 48	Noun_S	duppist
# 49	Noun_S	duskist
# 50	Noun_S	dutingist
# 51	Noun_S	ecoster
# 52	Noun_S	eluper
# 53	Noun_S	elusist
# 54	Noun_S	enlator
# 55	Noun_S	fallengist
# 56	Noun_S	fantivist
# 57	Noun_S	flingerician
# 58	Noun_S	flingerist
# 59	Noun_S	formantor
# 59	Noun_S	formantor
# 61	Noun_S	fossician
# 62	Noun_S	fragion
# 63	Noun_S	framitator
# 64	Noun_S	frawkess
# 65	Noun_S	fremator
# 66	Noun_S	froacher
# 67	Noun_S	frominaler
# 68	Noun_S	frominalist
# 69	Noun_S	fumitist
# 70	Noun_S	fusbender
# 71	Noun_S	gangerist
# 72	Noun_S	gezziman
# 73	Noun_S	gloralizer
# 74	Noun_S	gratenist
# 75	Noun_S	guendor
# 76	Noun_S	gumitist
# 77	Noun_S	gustist
# 78	Noun_S	hane
# 79	Noun_S	haustist
# 80	Noun_S	hilldomer
# 81	Noun_S	horrier
# 82	Noun_S	hostician
# 83	Noun_S	hostist
# 84	Noun_S	hule
# 85	Noun_S	humician
# 86	Noun_S	jantomer
# 87	Noun_S	jobsticator
# 88	Noun_S	jonter
# 89	Noun_S	justator
# 90	Noun_S	kaidist
# 91	Noun_S	kewardessor
# 92	Noun_S	kuestor
# 93	Noun_S	lactimer
# 94	Noun_S	lactissist
# 95	Noun_S	lawticater
# 96	Noun_S	lenn
# 97	Noun_S	lurchist
# 98	Noun_S	lustodist
# 99	Noun_S	madetor
# 100	Noun_S	mafe
# 101	Noun_S	mafflitist
# 102	Noun_S	melottess
# 103	Noun_S	mespician
# 104	Noun_S	midician
# 105	Noun_S	milturor
# 106	Noun_S	mofustator
# 107	Noun_S	moldician
# 108	Noun_S	naridator
# 109	Noun_S	narter
# 110	Noun_S	nestator
# 111	Noun_S	noacher
# 112	Noun_S	nust
# 113	Noun_S	pactesse
# 114	Noun_S	peachician
# 115	Noun_S	peagerist
# 116	Noun_S	penesser
# 117	Noun_S	penursifer
# 118	Noun_S	pilobist
# 119	Noun_S	pleddist
# 120	Noun_S	povician
# 121	Noun_S	predignor
# 122	Noun_S	prither
# 123	Noun_S	protter
# 124	Noun_S	purgettor
# 125	Noun_S	ranater
# 126	Noun_S	rattiner
# 127	Noun_S	redullor
# 128	Noun_S	ricatite
# 129	Noun_S	ronder
# 130	Noun_S	senth
# 131	Noun_S	serd
# 132	Noun_S	serg
# 133	Noun_S	sergator
# 134	Noun_S	shagoner
# 135	Noun_S	sherician
# 136	Noun_S	shodderist
# 137	Noun_S	siverthist
# 138	Noun_S	smoob
# 139	Noun_S	stimper
# 140	Noun_S	stoppist
# 141	Noun_S	stourt
# 142	Noun_S	streachor
# 143	Noun_S	stremorder
# 144	Noun_S	striberist
# 145	Noun_S	stroater
# 146	Noun_S	strogessor
# 147	Noun_S	tharoner
# 148	Noun_S	theslirist
# 149	Noun_S	thullamor
# 150	Noun_S	thullician
# 151	Noun_S	tib
# 152	Noun_S	tiraster
# 153	Noun_S	trachier
# 154	Noun_S	trapenist
# 155	Noun_S	trenner
# 156	Noun_S	visivet
# 157	Noun_S	voncenist
# 158	Noun_S	wainster
# 159	Noun_S	wanner
# 160	Noun_S	wolarist
# 161	Noun_S	wotanker
# 162	Noun_S	wuther
# 1	Noun_P	amackists
# 2	Noun_P	amationists
# 3	Noun_P	ambathers
# 4	Noun_P	ampercials
# 5	Noun_P	appalates
# 6	Noun_P	autoners
# 7	Noun_P	bactivitors
# 8	Noun_P	ballisons
# 9	Noun_P	baniticians
# 10	Noun_P	bellions
# 11	Noun_P	benaticians
# 12	Noun_P	bleckmans
# 13	Noun_P	blopes
# 14	Noun_P	bolicaters
# 15	Noun_P	bolicians
# 16	Noun_P	bolitists
# 17	Noun_P	botigners
# 18	Noun_P	bottists
# 19	Noun_P	breapers
# 20	Noun_P	brellands
# 21	Noun_P	briticists
# 21	Noun_P	briticists
# 23	Noun_P	buestors
# 24	Noun_P	bullagers
# 25	Noun_P	bullawers
# 26	Noun_P	bullifs
# 27	Noun_P	bullifists
# 28	Noun_P	bunessators
# 29	Noun_P	burses
# 30	Noun_P	businators
# 31	Noun_P	businers
# 32	Noun_P	calinelists
# 33	Noun_P	cheldors
# 34	Noun_P	croticians
# 35	Noun_P	crotifers
# 36	Noun_P	cushars
# 37	Noun_P	dakes
# 38	Noun_P	dargines
# 39	Noun_P	denaticians
# 40	Noun_P	doloners
# 41	Noun_P	dolonicians
# 42	Noun_P	dorpals
# 43	Noun_P	dorpalists
# 44	Noun_P	dracconts
# 45	Noun_P	drinimats
# 46	Noun_P	droinists
# 47	Noun_P	drousemans
# 48	Noun_P	duppists
# 49	Noun_P	duskists
# 50	Noun_P	dutingists
# 51	Noun_P	ecosters
# 52	Noun_P	elupers
# 53	Noun_P	elusists
# 54	Noun_P	enlators
# 55	Noun_P	fallengists
# 56	Noun_P	fantivists
# 57	Noun_P	flingericians
# 58	Noun_P	flingerists
# 59	Noun_P	formantors
# 59	Noun_P	formantors
# 61	Noun_P	fossicians
# 62	Noun_P	fragions
# 63	Noun_P	framitators
# 64	Noun_P	frawkesses
# 65	Noun_P	fremators
# 66	Noun_P	froachers
# 67	Noun_P	frominalers
# 68	Noun_P	frominalists
# 69	Noun_P	fumitists
# 70	Noun_P	fusbenders
# 71	Noun_P	gangerists
# 72	Noun_P	gezzimans
# 73	Noun_P	gloralizers
# 74	Noun_P	gratenists
# 75	Noun_P	guendors
# 76	Noun_P	gumitists
# 77	Noun_P	gustists
# 78	Noun_P	hanes
# 79	Noun_P	haustists
# 80	Noun_P	hilldomers
# 81	Noun_P	horriers
# 82	Noun_P	hosticians
# 83	Noun_P	hostists
# 84	Noun_P	hules
# 85	Noun_P	humicians
# 86	Noun_P	jantomers
# 87	Noun_P	jobsticators
# 88	Noun_P	jonters
# 89	Noun_P	justators
# 90	Noun_P	kaidists
# 91	Noun_P	kewardessors
# 92	Noun_P	kuestors
# 93	Noun_P	lactimers
# 94	Noun_P	lactissists
# 95	Noun_P	lawticaters
# 96	Noun_P	lenns
# 97	Noun_P	lurchists
# 98	Noun_P	lustodists
# 99	Noun_P	madetors
# 100	Noun_P	mafes
# 101	Noun_P	mafflitists
# 102	Noun_P	melottesses
# 103	Noun_P	mespicians
# 104	Noun_P	midicians
# 105	Noun_P	milturors
# 106	Noun_P	mofustators
# 107	Noun_P	moldicians
# 108	Noun_P	naridators
# 109	Noun_P	narters
# 110	Noun_P	nestators
# 111	Noun_P	noachers
# 112	Noun_P	nusts
# 113	Noun_P	pactesses
# 114	Noun_P	peachicians
# 115	Noun_P	peagerists
# 116	Noun_P	penessers
# 117	Noun_P	penursifers
# 118	Noun_P	pilobists
# 119	Noun_P	pleddists
# 120	Noun_P	povicians
# 121	Noun_P	predignors
# 122	Noun_P	prithers
# 123	Noun_P	protters
# 124	Noun_P	purgettors
# 125	Noun_P	ranaters
# 126	Noun_P	rattiners
# 127	Noun_P	redullors
# 128	Noun_P	ricatites
# 129	Noun_P	ronders
# 130	Noun_P	senths
# 131	Noun_P	serds
# 132	Noun_P	sergs
# 133	Noun_P	sergators
# 134	Noun_P	shagoners
# 135	Noun_P	shericians
# 136	Noun_P	shodderists
# 137	Noun_P	siverthists
# 138	Noun_P	smoobs
# 139	Noun_P	stimpers
# 140	Noun_P	stoppists
# 141	Noun_P	stourts
# 142	Noun_P	streachors
# 143	Noun_P	stremorders
# 144	Noun_P	striberists
# 145	Noun_P	stroaters
# 146	Noun_P	strogessors
# 147	Noun_P	tharoners
# 148	Noun_P	theslirists
# 149	Noun_P	thullamors
# 150	Noun_P	thullicians
# 151	Noun_P	tibs
# 152	Noun_P	tirasters
# 153	Noun_P	trachiers
# 154	Noun_P	trapenists
# 155	Noun_P	trenners
# 156	Noun_P	visivets
# 157	Noun_P	voncenists
# 158	Noun_P	wainsters
# 159	Noun_P	wanners
# 160	Noun_P	wolarists
# 161	Noun_P	wotankers
# 162	Noun_P	wuthers
# 1	Adj	prask
# 2	Adj	spange
# 3	Adj	crene
# 4	Adj	jurb
# 5	Adj	bilth
# 6	Adj	streck
# 7	Adj	skame
# 8	Adj	darsh
# 9	Adj	shrop
# 10	Adj	blide
# 11	Adj	breight
# 12	Adj	jawp
# 13	Adj	plonth
# 14	Adj	threak
# 15	Adj	dreek
# 16	Adj	meech
# 17	Adj	skeer
# 18	Adj	zild
# 19	Adj	jeethe
# 20	Adj	clim
# 21	Adj	spean
# 22	Adj	frub
# 23	Adj	douch
# 24	Adj	thrope
# 25	Adj	yeige
# 26	Adj	gaunch
# 27	Adj	gringe
# 28	Adj	ghump
# 29	Adj	yerg
# 30	Adj	scooth
# 31	Adj	fumit
# 32	Adj	stremord
# 33	Adj	purgett
# 34	Adj	jont
# 35	Adj	calin
# 36	Adj	naid
# 37	Adj	hild
# 38	Adj	botig
# 39	Adj	fusbend
# 40	Adj	guend
# 41	Adj	wuth
# 42	Adj	tharon
# 1	Verb_Comp_Past_S	engarified
# 2	Verb_Comp_Past_S	kurched
# 3	Verb_Comp_Past_S	formanated
# 4	Verb_Comp_Past_S	crailed
# 5	Verb_Comp_Past_S	lurchified
# 6	Verb_Comp_Past_S	fanched
# 7	Verb_Comp_Past_S	prutified
# 8	Verb_Comp_Past_S	squailed
# 9	Verb_Comp_Past_S	nobed
# 10	Verb_Comp_Past_S	pactessed
# 11	Verb_Comp_Past_S	sedundified
# 12	Verb_Comp_Past_S	sergatized
# 13	Verb_Comp_Past_S	unseffed
# 14	Verb_Comp_Past_S	buled
# 15	Verb_Comp_Past_S	humicianed
# 16	Verb_Comp_Past_S	saunched
# 17	Verb_Comp_Past_S	thespired
# 18	Verb_Comp_Past_S	conturized
# 19	Verb_Comp_Past_S	mangered
# 20	Verb_Comp_Past_S	strovokicized
# 21	Verb_Comp_Past_S	embarricated
# 22	Verb_Comp_Past_S	crinned
# 1	Verb_Comp_Past_P	engarifieda
# 2	Verb_Comp_Past_P	kurcheda
# 3	Verb_Comp_Past_P	formanateda
# 4	Verb_Comp_Past_P	craileda
# 5	Verb_Comp_Past_P	lurchifieda
# 6	Verb_Comp_Past_P	fancheda
# 7	Verb_Comp_Past_P	prutifieda
# 8	Verb_Comp_Past_P	squaileda
# 9	Verb_Comp_Past_P	nobeda
# 10	Verb_Comp_Past_P	pactesseda
# 11	Verb_Comp_Past_P	sedundifieda
# 12	Verb_Comp_Past_P	sergatizeda
# 13	Verb_Comp_Past_P	unseffeda
# 14	Verb_Comp_Past_P	buleda
# 15	Verb_Comp_Past_P	humicianeda
# 16	Verb_Comp_Past_P	sauncheda
# 17	Verb_Comp_Past_P	thespireda
# 18	Verb_Comp_Past_P	conturizeda
# 19	Verb_Comp_Past_P	mangereda
# 20	Verb_Comp_Past_P	strovokicizeda
# 21	Verb_Comp_Past_P	embarricateda
# 22	Verb_Comp_Past_P	crinneda
# 1	IVerb_Past_S	fusilitated
# 2	IVerb_Past_S	remiffed
# 3	IVerb_Past_S	mangerized
# 4	IVerb_Past_S	plessicated
# 5	IVerb_Past_S	wogged
# 6	IVerb_Past_S	forigated
# 7	IVerb_Past_S	vemed
# 8	IVerb_Past_S	phanicized
# 9	IVerb_Past_S	denaticated
# 10	IVerb_Past_S	gasted
# 11	IVerb_Past_S	peaserized
# 12	IVerb_Past_S	piliciated
# 13	IVerb_Past_S	hurperated
# 14	IVerb_Past_S	ralmed
# 15	IVerb_Past_S	charched
# 16	IVerb_Past_S	filked
# 17	IVerb_Past_S	tawlerized
# 18	IVerb_Past_S	onstigipated
# 19	IVerb_Past_S	rolved
# 19	IVerb_Past_S	rolved
# 21	IVerb_Past_S	offalded
# 22	IVerb_Past_S	calikated
# 23	IVerb_Past_S	mauced
# 24	IVerb_Past_S	inthippenated
# 25	IVerb_Past_S	visified
# 26	IVerb_Past_S	froachered
# 27	IVerb_Past_S	madressized
# 28	IVerb_Past_S	benaticianed
# 29	IVerb_Past_S	plessicked
# 30	IVerb_Past_S	scupped
# 31	IVerb_Past_S	framitatored
# 32	IVerb_Past_S	thrombicized
# 33	IVerb_Past_S	portified
# 34	IVerb_Past_S	tirasted
# 35	IVerb_Past_S	osmissified
# 36	IVerb_Past_S	peachicianed
# 37	IVerb_Past_S	scoaned
# 38	IVerb_Past_S	amackated
# 39	IVerb_Past_S	unplewed
# 40	IVerb_Past_S	jantomized
# 41	IVerb_Past_S	allacked
# 42	IVerb_Past_S	thullamized
# 43	IVerb_Past_S	smeshed
# 44	IVerb_Past_S	tismissated
# 45	IVerb_Past_S	offaldicated
# 46	IVerb_Past_S	briminated
# 47	IVerb_Past_S	maksized
# 48	IVerb_Past_S	amberated
# 49	IVerb_Past_S	amacked
# 50	IVerb_Past_S	apturicized
# 51	IVerb_Past_S	barsed
# 52	IVerb_Past_S	mofustated
# 53	IVerb_Past_S	broaled
# 54	IVerb_Past_S	fampenated
# 55	IVerb_Past_S	thespirated
# 56	IVerb_Past_S	parled
# 57	IVerb_Past_S	thrubbed
# 58	IVerb_Past_S	tarsed
# 59	IVerb_Past_S	teeved
# 60	IVerb_Past_S	revalternated
# 61	IVerb_Past_S	noachated
# 62	IVerb_Past_S	flapperated
# 63	IVerb_Past_S	mued
# 64	IVerb_Past_S	miticurized
# 65	IVerb_Past_S	saffled
# 66	IVerb_Past_S	chorried
# 67	IVerb_Past_S	excribited
# 68	IVerb_Past_S	lurchified
# 69	IVerb_Past_S	sturked
# 70	IVerb_Past_S	nestatated
# 71	IVerb_Past_S	limbatized
# 72	IVerb_Past_S	rotectified
# 73	IVerb_Past_S	swarmicated
# 74	IVerb_Past_S	prausified
# 75	IVerb_Past_S	elusified
# 76	IVerb_Past_S	spectified
# 77	IVerb_Past_S	annoriciated
# 78	IVerb_Past_S	elupized
# 79	IVerb_Past_S	lactissated
# 80	IVerb_Past_S	streachified
# 81	IVerb_Past_S	mattakated
# 82	IVerb_Past_S	ballicized
# 83	IVerb_Past_S	dupped
# 84	IVerb_Past_S	mofusted
# 85	IVerb_Past_S	yawled
# 86	IVerb_Past_S	striberated
# 87	IVerb_Past_S	treaved
# 88	IVerb_Past_S	mermillated
# 89	IVerb_Past_S	prottized
# 90	IVerb_Past_S	wolarified
# 91	IVerb_Past_S	gratenized
# 92	IVerb_Past_S	intrinsed
# 93	IVerb_Past_S	skeezed
# 94	IVerb_Past_S	rawned
# 95	IVerb_Past_S	tirastified
# 96	IVerb_Past_S	yolved
# 97	IVerb_Past_S	bunessisted
# 98	IVerb_Past_S	damerticated
# 99	IVerb_Past_S	peagerized
# 100	IVerb_Past_S	stoppisted
# 101	IVerb_Past_S	engaried
# 102	IVerb_Past_S	bottisted
# 103	IVerb_Past_S	bactivitated
# 104	IVerb_Past_S	greanerized
# 105	IVerb_Past_S	duppified
# 106	IVerb_Past_S	zurched
# 107	IVerb_Past_S	stroved
# 108	IVerb_Past_S	povicated
# 109	IVerb_Past_S	lavoidified
# 110	IVerb_Past_S	garfed
# 111	IVerb_Past_S	crotified
# 112	IVerb_Past_S	wandified
# 113	IVerb_Past_S	poutered
# 1	IVerb_Past_P	fusilitateda
# 2	IVerb_Past_P	remiffeda
# 3	IVerb_Past_P	mangerizeda
# 4	IVerb_Past_P	plessicateda
# 5	IVerb_Past_P	woggeda
# 6	IVerb_Past_P	forigateda
# 7	IVerb_Past_P	vemeda
# 8	IVerb_Past_P	phanicizeda
# 9	IVerb_Past_P	denaticateda
# 10	IVerb_Past_P	gasteda
# 11	IVerb_Past_P	peaserizeda
# 12	IVerb_Past_P	piliciateda
# 13	IVerb_Past_P	hurperateda
# 14	IVerb_Past_P	ralmeda
# 15	IVerb_Past_P	charcheda
# 16	IVerb_Past_P	filkeda
# 17	IVerb_Past_P	tawlerizeda
# 18	IVerb_Past_P	onstigipateda
# 19	IVerb_Past_P	rolveda
# 19	IVerb_Past_P	rolveda
# 21	IVerb_Past_P	offaldeda
# 22	IVerb_Past_P	calikateda
# 23	IVerb_Past_P	mauceda
# 24	IVerb_Past_P	inthippenateda
# 25	IVerb_Past_P	visifieda
# 26	IVerb_Past_P	froachereda
# 27	IVerb_Past_P	madressizeda
# 28	IVerb_Past_P	benaticianeda
# 29	IVerb_Past_P	plessickeda
# 30	IVerb_Past_P	scuppeda
# 31	IVerb_Past_P	framitatoreda
# 32	IVerb_Past_P	thrombicizeda
# 33	IVerb_Past_P	portifieda
# 34	IVerb_Past_P	tirasteda
# 35	IVerb_Past_P	osmissifieda
# 36	IVerb_Past_P	peachicianeda
# 37	IVerb_Past_P	scoaneda
# 38	IVerb_Past_P	amackateda
# 39	IVerb_Past_P	unpleweda
# 40	IVerb_Past_P	jantomizeda
# 41	IVerb_Past_P	allackeda
# 42	IVerb_Past_P	thullamizeda
# 43	IVerb_Past_P	smesheda
# 44	IVerb_Past_P	tismissateda
# 45	IVerb_Past_P	offaldicateda
# 46	IVerb_Past_P	briminateda
# 47	IVerb_Past_P	maksizeda
# 48	IVerb_Past_P	amberateda
# 49	IVerb_Past_P	amackeda
# 50	IVerb_Past_P	apturicizeda
# 51	IVerb_Past_P	barseda
# 52	IVerb_Past_P	mofustateda
# 53	IVerb_Past_P	broaleda
# 54	IVerb_Past_P	fampenateda
# 55	IVerb_Past_P	thespirateda
# 56	IVerb_Past_P	parleda
# 57	IVerb_Past_P	thrubbeda
# 58	IVerb_Past_P	tarseda
# 59	IVerb_Past_P	teeveda
# 60	IVerb_Past_P	revalternateda
# 61	IVerb_Past_P	noachateda
# 62	IVerb_Past_P	flapperateda
# 63	IVerb_Past_P	mueda
# 64	IVerb_Past_P	miticurizeda
# 65	IVerb_Past_P	saffleda
# 66	IVerb_Past_P	chorrieda
# 67	IVerb_Past_P	excribiteda
# 68	IVerb_Past_P	lurchifieda
# 69	IVerb_Past_P	sturkeda
# 70	IVerb_Past_P	nestatateda
# 71	IVerb_Past_P	limbatizeda
# 72	IVerb_Past_P	rotectifieda
# 73	IVerb_Past_P	swarmicateda
# 74	IVerb_Past_P	prausifieda
# 75	IVerb_Past_P	elusifieda
# 76	IVerb_Past_P	spectifieda
# 77	IVerb_Past_P	annoriciateda
# 78	IVerb_Past_P	elupizeda
# 79	IVerb_Past_P	lactissateda
# 80	IVerb_Past_P	streachifieda
# 81	IVerb_Past_P	mattakateda
# 82	IVerb_Past_P	ballicizeda
# 83	IVerb_Past_P	duppeda
# 84	IVerb_Past_P	mofusteda
# 85	IVerb_Past_P	yawleda
# 86	IVerb_Past_P	striberateda
# 87	IVerb_Past_P	treaveda
# 88	IVerb_Past_P	mermillateda
# 89	IVerb_Past_P	prottizeda
# 90	IVerb_Past_P	wolarifieda
# 91	IVerb_Past_P	gratenizeda
# 92	IVerb_Past_P	intrinseda
# 93	IVerb_Past_P	skeezeda
# 94	IVerb_Past_P	rawneda
# 95	IVerb_Past_P	tirastifieda
# 96	IVerb_Past_P	yolveda
# 97	IVerb_Past_P	bunessisteda
# 98	IVerb_Past_P	damerticateda
# 99	IVerb_Past_P	peagerizeda
# 100	IVerb_Past_P	stoppisteda
# 101	IVerb_Past_P	engarieda
# 102	IVerb_Past_P	bottisteda
# 103	IVerb_Past_P	bactivitateda
# 104	IVerb_Past_P	greanerizeda
# 105	IVerb_Past_P	duppifieda
# 106	IVerb_Past_P	zurcheda
# 107	IVerb_Past_P	stroveda
# 108	IVerb_Past_P	povicateda
# 109	IVerb_Past_P	lavoidifieda
# 110	IVerb_Past_P	garfeda
# 111	IVerb_Past_P	crotifieda
# 112	IVerb_Past_P	wandifieda
# 113	IVerb_Past_P	poutereda
# 1	TVerb_Past_S	gratenized
# 2	TVerb_Past_S	intrinsed
# 3	TVerb_Past_S	skeezed
# 4	TVerb_Past_S	rawned
# 5	TVerb_Past_S	tirastified
# 6	TVerb_Past_S	yolved
# 7	TVerb_Past_S	bunessisted
# 8	TVerb_Past_S	damerticated
# 9	TVerb_Past_S	peagerized
# 10	TVerb_Past_S	stoppisted
# 11	TVerb_Past_S	engaried
# 12	TVerb_Past_S	bottisted
# 13	TVerb_Past_S	bactivitated
# 14	TVerb_Past_S	greanerized
# 15	TVerb_Past_S	duppified
# 16	TVerb_Past_S	zurched
# 17	TVerb_Past_S	stroved
# 18	TVerb_Past_S	povicated
# 19	TVerb_Past_S	lavoidified
# 20	TVerb_Past_S	garfed
# 21	TVerb_Past_S	crotified
# 22	TVerb_Past_S	wandified
# 23	TVerb_Past_S	poutered
# 24	TVerb_Past_S	rebinked
# 25	TVerb_Past_S	dafed
# 26	TVerb_Past_S	bullegated
# 27	TVerb_Past_S	enjurified
# 28	TVerb_Past_S	visified
# 29	TVerb_Past_S	gumitified
# 30	TVerb_Past_S	baniticated
# 31	TVerb_Past_S	haustisted
# 32	TVerb_Past_S	pipistrated
# 33	TVerb_Past_S	povified
# 34	TVerb_Past_S	stribered
# 35	TVerb_Past_S	ninged
# 36	TVerb_Past_S	mafflitated
# 37	TVerb_Past_S	mafflicated
# 38	TVerb_Past_S	pleddisated
# 39	TVerb_Past_S	droverated
# 40	TVerb_Past_S	nulpened
# 41	TVerb_Past_S	thralled
# 42	TVerb_Past_S	maffliced
# 43	TVerb_Past_S	yossed
# 44	TVerb_Past_S	mespicated
# 45	TVerb_Past_S	spooled
# 46	TVerb_Past_S	frematized
# 47	TVerb_Past_S	disfrinsed
# 48	TVerb_Past_S	kippigated
# 49	TVerb_Past_S	lawticianed
# 50	TVerb_Past_S	apturicized
# 51	TVerb_Past_S	fossicated
# 52	TVerb_Past_S	blarped
# 53	TVerb_Past_S	phonorized
# 54	TVerb_Past_S	saultified
# 55	TVerb_Past_S	simpuridated
# 56	TVerb_Past_S	jontified
# 57	TVerb_Past_S	gratened
# 58	TVerb_Past_S	sosked
# 59	TVerb_Past_S	droled
# 60	TVerb_Past_S	chutched
# 61	TVerb_Past_S	bolicized
# 62	TVerb_Past_S	praimed
# 63	TVerb_Past_S	missiped
# 64	TVerb_Past_S	strubdified
# 65	TVerb_Past_S	strozed
# 66	TVerb_Past_S	blamiciated
# 67	TVerb_Past_S	bubbed
# 68	TVerb_Past_S	botticated
# 69	TVerb_Past_S	missipated
# 70	TVerb_Past_S	croicerated
# 71	TVerb_Past_S	fallengized
# 72	TVerb_Past_S	slurked
# 73	TVerb_Past_S	traived
# 74	TVerb_Past_S	conveamed
# 75	TVerb_Past_S	dupressified
# 76	TVerb_Past_S	phoisified
# 77	TVerb_Past_S	zamped
# 78	TVerb_Past_S	dupressed
# 79	TVerb_Past_S	draused
# 80	TVerb_Past_S	prockified
# 81	TVerb_Past_S	annoriciated
# 82	TVerb_Past_S	jeaped
# 83	TVerb_Past_S	pandicated
# 84	TVerb_Past_S	tissed
# 85	TVerb_Past_S	draired
# 86	TVerb_Past_S	theslirated
# 87	TVerb_Past_S	midicated
# 88	TVerb_Past_S	clummed
# 89	TVerb_Past_S	kuestified
# 90	TVerb_Past_S	peagified
# 91	TVerb_Past_S	glucked
# 92	TVerb_Past_S	madetized
# 93	TVerb_Past_S	croiled
# 94	TVerb_Past_S	lustodisted
# 95	TVerb_Past_S	tirastized
# 96	TVerb_Past_S	penursifered
# 97	TVerb_Past_S	dismaffed
# 98	TVerb_Past_S	chozed
# 99	TVerb_Past_S	justatored
# 100	TVerb_Past_S	frained
# 101	TVerb_Past_S	thafassized
# 27	TVerb_Past_S	enjurified
# 103	TVerb_Past_S	joofed
# 104	TVerb_Past_S	likiciated
# 105	TVerb_Past_S	pouteratized
# 106	TVerb_Past_S	irriticiated
# 107	TVerb_Past_S	blitched
# 108	TVerb_Past_S	gangeristed
# 109	TVerb_Past_S	stickerated
# 110	TVerb_Past_S	jobsticatored
# 111	TVerb_Past_S	scolterized
# 112	TVerb_Past_S	shumpified
# 113	TVerb_Past_S	heferated
# 1	TVerb_Past_P	gratenizeda
# 2	TVerb_Past_P	intrinseda
# 3	TVerb_Past_P	skeezeda
# 4	TVerb_Past_P	rawneda
# 5	TVerb_Past_P	tirastifieda
# 6	TVerb_Past_P	yolveda
# 7	TVerb_Past_P	bunessisteda
# 8	TVerb_Past_P	damerticateda
# 9	TVerb_Past_P	peagerizeda
# 10	TVerb_Past_P	stoppisteda
# 11	TVerb_Past_P	engarieda
# 12	TVerb_Past_P	bottisteda
# 13	TVerb_Past_P	bactivitateda
# 14	TVerb_Past_P	greanerizeda
# 15	TVerb_Past_P	duppifieda
# 16	TVerb_Past_P	zurcheda
# 17	TVerb_Past_P	stroveda
# 18	TVerb_Past_P	povicateda
# 19	TVerb_Past_P	lavoidifieda
# 20	TVerb_Past_P	garfeda
# 21	TVerb_Past_P	crotifieda
# 22	TVerb_Past_P	wandifieda
# 23	TVerb_Past_P	poutereda
# 24	TVerb_Past_P	rebinkeda
# 25	TVerb_Past_P	dafeda
# 26	TVerb_Past_P	bullegateda
# 27	TVerb_Past_P	enjurifieda
# 28	TVerb_Past_P	visifieda
# 29	TVerb_Past_P	gumitifieda
# 30	TVerb_Past_P	baniticateda
# 31	TVerb_Past_P	haustisteda
# 32	TVerb_Past_P	pipistrateda
# 33	TVerb_Past_P	povifieda
# 34	TVerb_Past_P	stribereda
# 35	TVerb_Past_P	ningeda
# 36	TVerb_Past_P	mafflitateda
# 37	TVerb_Past_P	mafflicateda
# 38	TVerb_Past_P	pleddisateda
# 39	TVerb_Past_P	droverateda
# 40	TVerb_Past_P	nulpeneda
# 41	TVerb_Past_P	thralleda
# 42	TVerb_Past_P	maffliceda
# 43	TVerb_Past_P	yosseda
# 44	TVerb_Past_P	mespicateda
# 45	TVerb_Past_P	spooleda
# 46	TVerb_Past_P	frematizeda
# 47	TVerb_Past_P	disfrinseda
# 48	TVerb_Past_P	kippigateda
# 49	TVerb_Past_P	lawticianeda
# 50	TVerb_Past_P	apturicizeda
# 51	TVerb_Past_P	fossicateda
# 52	TVerb_Past_P	blarpeda
# 53	TVerb_Past_P	phonorizeda
# 54	TVerb_Past_P	saultifieda
# 55	TVerb_Past_P	simpuridateda
# 56	TVerb_Past_P	jontifieda
# 57	TVerb_Past_P	grateneda
# 58	TVerb_Past_P	soskeda
# 59	TVerb_Past_P	droleda
# 60	TVerb_Past_P	chutcheda
# 61	TVerb_Past_P	bolicizeda
# 62	TVerb_Past_P	praimeda
# 63	TVerb_Past_P	missipeda
# 64	TVerb_Past_P	strubdifieda
# 65	TVerb_Past_P	strozeda
# 66	TVerb_Past_P	blamiciateda
# 67	TVerb_Past_P	bubbeda
# 68	TVerb_Past_P	botticateda
# 69	TVerb_Past_P	missipateda
# 70	TVerb_Past_P	croicerateda
# 71	TVerb_Past_P	fallengizeda
# 72	TVerb_Past_P	slurkeda
# 73	TVerb_Past_P	traiveda
# 74	TVerb_Past_P	conveameda
# 75	TVerb_Past_P	dupressifieda
# 76	TVerb_Past_P	phoisifieda
# 77	TVerb_Past_P	zampeda
# 78	TVerb_Past_P	dupresseda
# 79	TVerb_Past_P	drauseda
# 80	TVerb_Past_P	prockifieda
# 81	TVerb_Past_P	annoriciateda
# 82	TVerb_Past_P	jeapeda
# 83	TVerb_Past_P	pandicateda
# 84	TVerb_Past_P	tisseda
# 85	TVerb_Past_P	draireda
# 86	TVerb_Past_P	theslirateda
# 87	TVerb_Past_P	midicateda
# 88	TVerb_Past_P	clummeda
# 89	TVerb_Past_P	kuestifieda
# 90	TVerb_Past_P	peagifieda
# 91	TVerb_Past_P	gluckeda
# 92	TVerb_Past_P	madetizeda
# 93	TVerb_Past_P	croileda
# 94	TVerb_Past_P	lustodisteda
# 95	TVerb_Past_P	tirastizeda
# 96	TVerb_Past_P	penursifereda
# 97	TVerb_Past_P	dismaffeda
# 98	TVerb_Past_P	chozeda
# 99	TVerb_Past_P	justatoreda
# 100	TVerb_Past_P	fraineda
# 101	TVerb_Past_P	thafassizeda
# 102	TVerb_Past_P	joofeda
# 103	TVerb_Past_P	likiciateda
# 104	TVerb_Past_P	pouteratizeda
# 105	TVerb_Past_P	irriticiateda
# 106	TVerb_Past_P	blitcheda
# 107	TVerb_Past_P	gangeristeda
# 108	TVerb_Past_P	stickerateda
# 109	TVerb_Past_P	jobsticatoreda
# 110	TVerb_Past_P	scolterizeda
# 111	TVerb_Past_P	shumpifieda
# 112	TVerb_Past_P	heferateda
# 1	Verb_Comp_Pres_S	engarifies
# 2	Verb_Comp_Pres_S	kurches
# 3	Verb_Comp_Pres_S	formanates
# 4	Verb_Comp_Pres_S	crails
# 5	Verb_Comp_Pres_S	lurchifies
# 6	Verb_Comp_Pres_S	fanches
# 7	Verb_Comp_Pres_S	prutifies
# 8	Verb_Comp_Pres_S	squails
# 9	Verb_Comp_Pres_S	nobs
# 10	Verb_Comp_Pres_S	pactesses
# 11	Verb_Comp_Pres_S	sedundifies
# 12	Verb_Comp_Pres_S	sergatizes
# 13	Verb_Comp_Pres_S	unseffs
# 14	Verb_Comp_Pres_S	bules
# 15	Verb_Comp_Pres_S	humicianes
# 16	Verb_Comp_Pres_S	saunches
# 17	Verb_Comp_Pres_S	thespires
# 18	Verb_Comp_Pres_S	conturizes
# 19	Verb_Comp_Pres_S	mangeres
# 20	Verb_Comp_Pres_S	strovokicizes
# 21	Verb_Comp_Pres_S	embarricates
# 22	Verb_Comp_Pres_S	crins
# 1	Verb_Comp_Pres_P	engarify
# 2	Verb_Comp_Pres_P	kurche
# 3	Verb_Comp_Pres_P	formanate
# 4	Verb_Comp_Pres_P	crail
# 5	Verb_Comp_Pres_P	lurchify
# 6	Verb_Comp_Pres_P	fanch
# 7	Verb_Comp_Pres_P	prutify
# 8	Verb_Comp_Pres_P	squail
# 9	Verb_Comp_Pres_P	nob
# 10	Verb_Comp_Pres_P	pactess
# 11	Verb_Comp_Pres_P	sedundify
# 12	Verb_Comp_Pres_P	sergatize
# 13	Verb_Comp_Pres_P	unseff
# 14	Verb_Comp_Pres_P	bule
# 15	Verb_Comp_Pres_P	humiciane
# 16	Verb_Comp_Pres_P	saunch
# 17	Verb_Comp_Pres_P	thespire
# 18	Verb_Comp_Pres_P	conturize
# 19	Verb_Comp_Pres_P	mangere
# 20	Verb_Comp_Pres_P	strovokicize
# 21	Verb_Comp_Pres_P	embarricate
# 22	Verb_Comp_Pres_P	crin
# 1	IVerb_Pres_S	fusilitates
# 2	IVerb_Pres_S	remiffs
# 3	IVerb_Pres_S	mangerizes
# 4	IVerb_Pres_S	plessicates
# 5	IVerb_Pres_S	wogs
# 6	IVerb_Pres_S	forigates
# 7	IVerb_Pres_S	vems
# 8	IVerb_Pres_S	phanicizes
# 9	IVerb_Pres_S	denaticates
# 10	IVerb_Pres_S	gasts
# 11	IVerb_Pres_S	peaserizes
# 12	IVerb_Pres_S	piliciates
# 13	IVerb_Pres_S	hurperates
# 14	IVerb_Pres_S	ralms
# 15	IVerb_Pres_S	charchs
# 16	IVerb_Pres_S	filks
# 17	IVerb_Pres_S	tawlerizes
# 18	IVerb_Pres_S	onstigipates
# 19	IVerb_Pres_S	rolves
# 19	IVerb_Pres_S	rolves
# 21	IVerb_Pres_S	offaldes
# 22	IVerb_Pres_S	calikates
# 23	IVerb_Pres_S	mauces
# 24	IVerb_Pres_S	inthippenates
# 25	IVerb_Pres_S	visifies
# 26	IVerb_Pres_S	froacheres
# 27	IVerb_Pres_S	madressizes
# 28	IVerb_Pres_S	benaticianes
# 29	IVerb_Pres_S	plessickes
# 30	IVerb_Pres_S	scupps
# 31	IVerb_Pres_S	framitatores
# 32	IVerb_Pres_S	thrombicizes
# 33	IVerb_Pres_S	portifies
# 34	IVerb_Pres_S	tirastes
# 35	IVerb_Pres_S	osmissifies
# 36	IVerb_Pres_S	peachicianes
# 37	IVerb_Pres_S	scoans
# 38	IVerb_Pres_S	amackates
# 39	IVerb_Pres_S	unplews
# 40	IVerb_Pres_S	jantomizes
# 41	IVerb_Pres_S	allacks
# 42	IVerb_Pres_S	thullamizes
# 43	IVerb_Pres_S	smeshs
# 44	IVerb_Pres_S	tismissates
# 45	IVerb_Pres_S	offaldicates
# 46	IVerb_Pres_S	briminates
# 47	IVerb_Pres_S	maksizes
# 48	IVerb_Pres_S	amberates
# 49	IVerb_Pres_S	amackes
# 50	IVerb_Pres_S	apturicizes
# 51	IVerb_Pres_S	barses
# 52	IVerb_Pres_S	mofustates
# 53	IVerb_Pres_S	broals
# 54	IVerb_Pres_S	fampenates
# 55	IVerb_Pres_S	thespirates
# 56	IVerb_Pres_S	parls
# 57	IVerb_Pres_S	thrubs
# 58	IVerb_Pres_S	tarses
# 59	IVerb_Pres_S	teeves
# 60	IVerb_Pres_S	revalternates
# 61	IVerb_Pres_S	noachates
# 62	IVerb_Pres_S	flapperates
# 63	IVerb_Pres_S	mues
# 64	IVerb_Pres_S	miticurizes
# 65	IVerb_Pres_S	saffles
# 66	IVerb_Pres_S	chorries
# 67	IVerb_Pres_S	excribits
# 68	IVerb_Pres_S	lurchifies
# 69	IVerb_Pres_S	sturks
# 70	IVerb_Pres_S	nestatates
# 71	IVerb_Pres_S	limbatizes
# 72	IVerb_Pres_S	rotectifies
# 73	IVerb_Pres_S	swarmicates
# 74	IVerb_Pres_S	prausifies
# 75	IVerb_Pres_S	elusifies
# 76	IVerb_Pres_S	spectifies
# 77	IVerb_Pres_S	annoriciates
# 78	IVerb_Pres_S	elupizes
# 79	IVerb_Pres_S	lactissates
# 80	IVerb_Pres_S	streachifies
# 81	IVerb_Pres_S	mattakates
# 82	IVerb_Pres_S	ballicizes
# 83	IVerb_Pres_S	dupps
# 84	IVerb_Pres_S	mofustes
# 85	IVerb_Pres_S	yawls
# 86	IVerb_Pres_S	striberates
# 87	IVerb_Pres_S	treaves
# 88	IVerb_Pres_S	mermillates
# 89	IVerb_Pres_S	prottizes
# 90	IVerb_Pres_S	wolarifies
# 91	IVerb_Pres_S	gratenizes
# 92	IVerb_Pres_S	intrinses
# 93	IVerb_Pres_S	skeezes
# 94	IVerb_Pres_S	rawns
# 95	IVerb_Pres_S	tirastifies
# 96	IVerb_Pres_S	yolves
# 97	IVerb_Pres_S	bunessistes
# 98	IVerb_Pres_S	damerticates
# 99	IVerb_Pres_S	peagerizes
# 100	IVerb_Pres_S	stoppistes
# 101	IVerb_Pres_S	engaries
# 102	IVerb_Pres_S	bottistes
# 103	IVerb_Pres_S	bactivitates
# 104	IVerb_Pres_S	greanerizes
# 105	IVerb_Pres_S	duppifies
# 106	IVerb_Pres_S	zurches
# 107	IVerb_Pres_S	stroves
# 108	IVerb_Pres_S	povicates
# 109	IVerb_Pres_S	lavoidifies
# 110	IVerb_Pres_S	garfs
# 111	IVerb_Pres_S	crotifies
# 112	IVerb_Pres_S	wandifies
# 113	IVerb_Pres_S	pouteres
# 1	IVerb_Pres_P	fusilitate
# 2	IVerb_Pres_P	remiff
# 3	IVerb_Pres_P	mangerize
# 4	IVerb_Pres_P	plessicate
# 5	IVerb_Pres_P	wog
# 6	IVerb_Pres_P	forigate
# 7	IVerb_Pres_P	vem
# 8	IVerb_Pres_P	phanicize
# 9	IVerb_Pres_P	denaticate
# 10	IVerb_Pres_P	gast
# 11	IVerb_Pres_P	peaserize
# 12	IVerb_Pres_P	piliciate
# 13	IVerb_Pres_P	hurperate
# 14	IVerb_Pres_P	ralm
# 15	IVerb_Pres_P	charch
# 16	IVerb_Pres_P	filk
# 17	IVerb_Pres_P	tawlerize
# 18	IVerb_Pres_P	onstigipate
# 19	IVerb_Pres_P	rolve
# 19	IVerb_Pres_P	rolve
# 21	IVerb_Pres_P	offalde
# 22	IVerb_Pres_P	calikate
# 23	IVerb_Pres_P	mauce
# 24	IVerb_Pres_P	inthippenate
# 25	IVerb_Pres_P	visify
# 26	IVerb_Pres_P	froachere
# 27	IVerb_Pres_P	madressize
# 28	IVerb_Pres_P	benaticiane
# 29	IVerb_Pres_P	plessicke
# 30	IVerb_Pres_P	scupp
# 31	IVerb_Pres_P	framitatore
# 32	IVerb_Pres_P	thrombicize
# 33	IVerb_Pres_P	portify
# 34	IVerb_Pres_P	tiraste
# 35	IVerb_Pres_P	osmissify
# 36	IVerb_Pres_P	peachiciane
# 37	IVerb_Pres_P	scoan
# 38	IVerb_Pres_P	amackate
# 39	IVerb_Pres_P	unplew
# 40	IVerb_Pres_P	jantomize
# 41	IVerb_Pres_P	allack
# 42	IVerb_Pres_P	thullamize
# 43	IVerb_Pres_P	smesh
# 44	IVerb_Pres_P	tismissate
# 45	IVerb_Pres_P	offaldicate
# 46	IVerb_Pres_P	briminate
# 47	IVerb_Pres_P	maksize
# 48	IVerb_Pres_P	amberate
# 49	IVerb_Pres_P	amacke
# 50	IVerb_Pres_P	apturicize
# 51	IVerb_Pres_P	barse
# 52	IVerb_Pres_P	mofustate
# 53	IVerb_Pres_P	broal
# 54	IVerb_Pres_P	fampenate
# 55	IVerb_Pres_P	thespirate
# 56	IVerb_Pres_P	parl
# 57	IVerb_Pres_P	thrub
# 58	IVerb_Pres_P	tarse
# 59	IVerb_Pres_P	teeve
# 60	IVerb_Pres_P	revalternate
# 61	IVerb_Pres_P	noachate
# 62	IVerb_Pres_P	flapperate
# 63	IVerb_Pres_P	mue
# 64	IVerb_Pres_P	miticurize
# 65	IVerb_Pres_P	saffle
# 66	IVerb_Pres_P	chorry
# 67	IVerb_Pres_P	excribit
# 68	IVerb_Pres_P	lurchify
# 69	IVerb_Pres_P	sturk
# 70	IVerb_Pres_P	nestatate
# 71	IVerb_Pres_P	limbatize
# 72	IVerb_Pres_P	rotectify
# 73	IVerb_Pres_P	swarmicate
# 74	IVerb_Pres_P	prausify
# 75	IVerb_Pres_P	elusify
# 76	IVerb_Pres_P	spectify
# 77	IVerb_Pres_P	annoriciate
# 78	IVerb_Pres_P	elupize
# 79	IVerb_Pres_P	lactissate
# 80	IVerb_Pres_P	streachify
# 81	IVerb_Pres_P	mattakate
# 82	IVerb_Pres_P	ballicize
# 83	IVerb_Pres_P	dupp
# 84	IVerb_Pres_P	mofuste
# 85	IVerb_Pres_P	yawl
# 86	IVerb_Pres_P	striberate
# 87	IVerb_Pres_P	treave
# 88	IVerb_Pres_P	mermillate
# 89	IVerb_Pres_P	prottize
# 90	IVerb_Pres_P	wolarify
# 91	IVerb_Pres_P	gratenize
# 92	IVerb_Pres_P	intrinse
# 93	IVerb_Pres_P	skeeze
# 94	IVerb_Pres_P	rawn
# 95	IVerb_Pres_P	tirastify
# 96	IVerb_Pres_P	yolve
# 97	IVerb_Pres_P	bunessiste
# 98	IVerb_Pres_P	damerticate
# 99	IVerb_Pres_P	peagerize
# 100	IVerb_Pres_P	stoppiste
# 101	IVerb_Pres_P	engary
# 102	IVerb_Pres_P	bottiste
# 103	IVerb_Pres_P	bactivitate
# 104	IVerb_Pres_P	greanerize
# 105	IVerb_Pres_P	duppify
# 106	IVerb_Pres_P	zurch
# 107	IVerb_Pres_P	strove
# 108	IVerb_Pres_P	povicate
# 109	IVerb_Pres_P	lavoidify
# 110	IVerb_Pres_P	garf
# 111	IVerb_Pres_P	crotify
# 112	IVerb_Pres_P	wandify
# 113	IVerb_Pres_P	poutere
# 1	TVerb_Pres_S	gratenizes
# 2	TVerb_Pres_S	intrinses
# 3	TVerb_Pres_S	skeezes
# 4	TVerb_Pres_S	rawns
# 5	TVerb_Pres_S	tirastifies
# 6	TVerb_Pres_S	yolves
# 7	TVerb_Pres_S	bunessistes
# 8	TVerb_Pres_S	damerticates
# 9	TVerb_Pres_S	peagerizes
# 10	TVerb_Pres_S	stoppistes
# 11	TVerb_Pres_S	engaries
# 12	TVerb_Pres_S	bottistes
# 13	TVerb_Pres_S	bactivitates
# 14	TVerb_Pres_S	greanerizes
# 15	TVerb_Pres_S	duppifies
# 16	TVerb_Pres_S	zurches
# 17	TVerb_Pres_S	stroves
# 18	TVerb_Pres_S	povicates
# 19	TVerb_Pres_S	lavoidifies
# 20	TVerb_Pres_S	garfs
# 21	TVerb_Pres_S	crotifies
# 22	TVerb_Pres_S	wandifies
# 23	TVerb_Pres_S	pouteres
# 24	TVerb_Pres_S	rebinks
# 25	TVerb_Pres_S	dafes
# 26	TVerb_Pres_S	bullegates
# 27	TVerb_Pres_S	enjurifies
# 28	TVerb_Pres_S	visifies
# 29	TVerb_Pres_S	gumitifies
# 30	TVerb_Pres_S	baniticates
# 31	TVerb_Pres_S	haustistes
# 32	TVerb_Pres_S	pipistrates
# 33	TVerb_Pres_S	povifies
# 34	TVerb_Pres_S	striberes
# 35	TVerb_Pres_S	nings
# 36	TVerb_Pres_S	mafflitates
# 37	TVerb_Pres_S	mafflicates
# 38	TVerb_Pres_S	pleddisates
# 39	TVerb_Pres_S	droverates
# 40	TVerb_Pres_S	nulpens
# 41	TVerb_Pres_S	thralls
# 42	TVerb_Pres_S	mafflices
# 43	TVerb_Pres_S	yosses
# 44	TVerb_Pres_S	mespicates
# 45	TVerb_Pres_S	spools
# 46	TVerb_Pres_S	frematizes
# 47	TVerb_Pres_S	disfrinses
# 48	TVerb_Pres_S	kippigates
# 49	TVerb_Pres_S	lawticianes
# 50	TVerb_Pres_S	apturicizes
# 51	TVerb_Pres_S	fossicates
# 52	TVerb_Pres_S	blarps
# 53	TVerb_Pres_S	phonorizes
# 54	TVerb_Pres_S	saultifies
# 55	TVerb_Pres_S	simpuridates
# 56	TVerb_Pres_S	jontifies
# 57	TVerb_Pres_S	gratenes
# 58	TVerb_Pres_S	sosks
# 59	TVerb_Pres_S	drols
# 60	TVerb_Pres_S	chutches
# 61	TVerb_Pres_S	bolicizes
# 62	TVerb_Pres_S	praims
# 63	TVerb_Pres_S	missipes
# 64	TVerb_Pres_S	strubdifies
# 65	TVerb_Pres_S	strozes
# 66	TVerb_Pres_S	blamiciates
# 67	TVerb_Pres_S	bubs
# 68	TVerb_Pres_S	botticates
# 69	TVerb_Pres_S	missipates
# 70	TVerb_Pres_S	croicerates
# 71	TVerb_Pres_S	fallengizes
# 72	TVerb_Pres_S	slurks
# 73	TVerb_Pres_S	traives
# 74	TVerb_Pres_S	conveams
# 75	TVerb_Pres_S	dupressifies
# 76	TVerb_Pres_S	phoisifies
# 77	TVerb_Pres_S	zamps
# 78	TVerb_Pres_S	dupresses
# 79	TVerb_Pres_S	drauses
# 80	TVerb_Pres_S	prockifies
# 81	TVerb_Pres_S	annoriciates
# 82	TVerb_Pres_S	jeaps
# 83	TVerb_Pres_S	pandicates
# 84	TVerb_Pres_S	tisses
# 85	TVerb_Pres_S	drairs
# 86	TVerb_Pres_S	theslirates
# 87	TVerb_Pres_S	midicates
# 88	TVerb_Pres_S	clums
# 89	TVerb_Pres_S	kuestifies
# 90	TVerb_Pres_S	peagifies
# 91	TVerb_Pres_S	glucks
# 92	TVerb_Pres_S	madetizes
# 93	TVerb_Pres_S	croils
# 94	TVerb_Pres_S	lustodistes
# 95	TVerb_Pres_S	tirastizes
# 96	TVerb_Pres_S	penursiferes
# 97	TVerb_Pres_S	dismaffes
# 98	TVerb_Pres_S	chozes
# 99	TVerb_Pres_S	justatores
# 100	TVerb_Pres_S	frains
# 101	TVerb_Pres_S	thafassizes
# 27	TVerb_Pres_S	enjurifies
# 103	TVerb_Pres_S	joofs
# 104	TVerb_Pres_S	likiciates
# 105	TVerb_Pres_S	pouteratizes
# 106	TVerb_Pres_S	irriticiates
# 107	TVerb_Pres_S	blitches
# 108	TVerb_Pres_S	gangeristes
# 109	TVerb_Pres_S	stickerates
# 110	TVerb_Pres_S	jobsticatores
# 111	TVerb_Pres_S	scolterizes
# 112	TVerb_Pres_S	shumpifies
# 113	TVerb_Pres_S	heferates
# 1	TVerb_Pres_P	gratenize
# 2	TVerb_Pres_P	intrinse
# 3	TVerb_Pres_P	skeez
# 4	TVerb_Pres_P	rawn
# 5	TVerb_Pres_P	tirastify
# 6	TVerb_Pres_P	yolve
# 7	TVerb_Pres_P	bunessiste
# 8	TVerb_Pres_P	damerticate
# 9	TVerb_Pres_P	peagerize
# 10	TVerb_Pres_P	stoppiste
# 11	TVerb_Pres_P	engary
# 12	TVerb_Pres_P	bottiste
# 13	TVerb_Pres_P	bactivitate
# 14	TVerb_Pres_P	greanerize
# 15	TVerb_Pres_P	duppify
# 16	TVerb_Pres_P	zurch
# 17	TVerb_Pres_P	strove
# 18	TVerb_Pres_P	povicate
# 19	TVerb_Pres_P	lavoidify
# 20	TVerb_Pres_P	garf
# 21	TVerb_Pres_P	crotify
# 22	TVerb_Pres_P	wandify
# 23	TVerb_Pres_P	poutere
# 24	TVerb_Pres_P	rebink
# 25	TVerb_Pres_P	dafe
# 26	TVerb_Pres_P	bullegate
# 27	TVerb_Pres_P	enjurify
# 28	TVerb_Pres_P	visify
# 29	TVerb_Pres_P	gumitify
# 30	TVerb_Pres_P	baniticate
# 31	TVerb_Pres_P	haustiste
# 32	TVerb_Pres_P	pipistrate
# 33	TVerb_Pres_P	povify
# 34	TVerb_Pres_P	stribere
# 35	TVerb_Pres_P	ning
# 36	TVerb_Pres_P	mafflitate
# 37	TVerb_Pres_P	mafflicate
# 38	TVerb_Pres_P	pleddisate
# 39	TVerb_Pres_P	droverate
# 40	TVerb_Pres_P	nulpen
# 41	TVerb_Pres_P	thrall
# 42	TVerb_Pres_P	mafflice
# 43	TVerb_Pres_P	yoss
# 44	TVerb_Pres_P	mespicate
# 45	TVerb_Pres_P	spool
# 46	TVerb_Pres_P	frematize
# 47	TVerb_Pres_P	disfrinse
# 48	TVerb_Pres_P	kippigate
# 49	TVerb_Pres_P	lawticiane
# 50	TVerb_Pres_P	apturicize
# 51	TVerb_Pres_P	fossicate
# 52	TVerb_Pres_P	blarp
# 53	TVerb_Pres_P	phonorize
# 54	TVerb_Pres_P	saultify
# 55	TVerb_Pres_P	simpuridate
# 56	TVerb_Pres_P	jontify
# 57	TVerb_Pres_P	gratene
# 58	TVerb_Pres_P	sosk
# 59	TVerb_Pres_P	drol
# 60	TVerb_Pres_P	chutch
# 61	TVerb_Pres_P	bolicize
# 62	TVerb_Pres_P	praim
# 63	TVerb_Pres_P	missipe
# 64	TVerb_Pres_P	strubdify
# 65	TVerb_Pres_P	stroze
# 66	TVerb_Pres_P	blamiciate
# 67	TVerb_Pres_P	bub
# 68	TVerb_Pres_P	botticate
# 69	TVerb_Pres_P	missipate
# 70	TVerb_Pres_P	croicerate
# 71	TVerb_Pres_P	fallengize
# 72	TVerb_Pres_P	slurk
# 73	TVerb_Pres_P	traive
# 74	TVerb_Pres_P	conveam
# 75	TVerb_Pres_P	dupressify
# 76	TVerb_Pres_P	phoisify
# 77	TVerb_Pres_P	zamp
# 78	TVerb_Pres_P	dupresse
# 79	TVerb_Pres_P	drause
# 80	TVerb_Pres_P	prockify
# 81	TVerb_Pres_P	annoriciate
# 82	TVerb_Pres_P	jeap
# 83	TVerb_Pres_P	pandicate
# 84	TVerb_Pres_P	tisse
# 85	TVerb_Pres_P	drair
# 86	TVerb_Pres_P	theslirate
# 87	TVerb_Pres_P	midicate
# 88	TVerb_Pres_P	clum
# 89	TVerb_Pres_P	kuestify
# 90	TVerb_Pres_P	peagify
# 91	TVerb_Pres_P	gluck
# 92	TVerb_Pres_P	madetize
# 93	TVerb_Pres_P	croil
# 94	TVerb_Pres_P	lustodiste
# 95	TVerb_Pres_P	tirastize
# 96	TVerb_Pres_P	penursifere
# 97	TVerb_Pres_P	dismaffe
# 98	TVerb_Pres_P	choze
# 99	TVerb_Pres_P	justatore
# 100	TVerb_Pres_P	frain
# 101	TVerb_Pres_P	thafassize
# 27	TVerb_Pres_P	enjurify
# 103	TVerb_Pres_P	joof
# 104	TVerb_Pres_P	likiciate
# 105	TVerb_Pres_P	pouteratize
# 106	TVerb_Pres_P	irriticiate
# 107	TVerb_Pres_P	blitch
# 108	TVerb_Pres_P	gangeriste
# 109	TVerb_Pres_P	stickerate
# 110	TVerb_Pres_P	jobsticatore
# 111	TVerb_Pres_P	scolterize
# 112	TVerb_Pres_P	shumpify
# 113	TVerb_Pres_P	heferate
# 1	Prep	ca
# 2	Prep	ma
# 3	Prep	hi
# 4	Prep	lu
# 1	CC	da
# 1	Comp	sa
# 1	Rel	rel
# 1	Subj	sub
# 1	Obj	ob
# 1	Pronoun_S	bo
# 2	Pronoun_S	se
# 3	Pronoun_S	pi
# 4	Pronoun_S	me
# 1	Pronoun_P	si
# 2	Pronoun_P	la
# 5	Pronoun_S	ja
# 1	EOS	[eos]
