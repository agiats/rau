# %%
import argparse
import os
import random


class PCFG:
    """
    PCFG to sample sentences from
    """
    def __init__(self, grammar_file):
        self.rules = None
        self.change_rules = None
        self.load_rules(grammar_file)

    def load_rules(self, grammar_file):
        new_rules = {}
        change = {}
        g_file = open(grammar_file, 'r')
        lines = g_file.readlines()
        for l in lines:
            if l.startswith(('#', " ", "\t", "\n")) or len(l) < 1:
                continue
            else:
                if l.find("#") != -1:
                    l = l[:l.find("#")]
                idx = -1
                if len(l.rstrip().split("\t")) == 3:
                    weight, lhs, rhs = l.rstrip().split("\t")
                elif len(l.rstrip().split("\t")) == 4:
                    weight, lhs, rhs, idx = l.rstrip().split("\t")
                if lhs not in new_rules.keys():
                    new_rules[lhs] = []
                poss_rhs = new_rules[lhs]
                poss_rhs.append([rhs, float(weight)])
                if idx != -1:
                    change[lhs + "\t" + rhs] = idx
        for lhs, poss in new_rules.items():
            total = 0
            for rhs in poss:
                total += rhs[1]
            for rhs in poss:
                rhs[1] /= total
        self.rules = new_rules
        self.change_rules = change

    def sample_sentence(self, max_expansions, bracketing):
        self.expansions = 0
        done = False
        sent = ["ROOT"]
        idx = 0
        while not done:
            if sent[idx] not in self.rules.keys():
                idx += 1
                if idx >= len(sent):
                    done = True
                continue
            else:
                replace, change_idx = self.expand(sent[idx])
                if bracketing:
                    if change_idx == -1:
                        sent = (sent[:idx]
                            + ["(", sent[idx]] + replace + [")"]
                            + sent[idx + 1:])
                    else:
                        sent = (sent[:idx]
                            + ["(", change_idx + sent[idx]] + replace + [")"]
                            + sent[idx + 1:])
                else:
                    sent = sent[:idx] + replace  + sent[idx + 1:]
                self.expansions += 1
                if bracketing:
                    idx += 2
                if self.expansions > max_expansions:
                    done = True
                if idx >= len(sent):
                    done = True
        if self.expansions > max_expansions:
            print("Max expansions reached")
            for idx in range(len(sent)):
                if not bracketing:
                    if sent[idx] in self.rules.keys():
                        sent[idx] = "..."
                else:
                    if sent[idx] in self.rules.keys() and sent[idx - 1] != "(":
                        sent[idx] = "..."
        return ' '.join(sent)

    def expand(self, symbol):
        poss = self.rules[symbol]
        sample = random.random()
        val = 0.0
        rhs = ""
        idx = -1
        for p in poss:
            val += p[1]
            if sample <= val:
                if symbol + "\t" + p[0] in self.change_rules.keys():
                    idx = self.change_rules[symbol + "\t" + p[0]]
                rhs = p[0]
                break
        return rhs.split(" "), idx

# %%
# monte carlo sampling and estimate probability of a sentence
n_sample = 1_000_000

def monte_carlo_estimation(grammar_file, max_expansions, n_sample):
    sentence_to_count = {}
    grammar = PCFG(grammar_file)
    for i in range(n_sample):
        sent = grammar.sample_sentence(max_expansions=max_expansions, False)
        if sent not in sentence_to_count.keys():
            sentence_to_count[sent] = 0
        sentence_to_count[sent] += 1

    return sentence_to_count

# %%
n_sample = 1_000_000
sentence_to_count = monte_carlo_estimation("data_gen/base-grammar_eos.gr", 400, n_sample)
# Out:
# Max expansions reached
# Max expansions reached
# Max expansions reached

# %%
sentence_to_prob = {k: v / n_sample for k, v in sentence_to_count.items()}
# Out:
# {'brelland sub calikated sa embarricate rel doloners sub inthippenated rel amackist ob blamiciateda [eos]': 1,
#  'gloralizers sub noachate [eos]': 1,
#  'crotifers sub la sub filk sa fancheda rel tibs ob baniticate [eos]': 1,
#  'botig denaticians sub naid shagoners sub froachereda sa thespireda [eos]': 1,
#  'revalternates rel bactivitor sub zurched [eos]': 1,
#  'naid wainsters sub flingerists ob chozed rel senth ob wandify sa embarricateda rel trachiers sub bunessistes rel businer sub garfs sa unseff [eos]': 1,
#  'pi sub thespirates [eos]': 31,
#  'naid stroaters sub me ob dupresse rel briticists ob croil [eos]': 1,
#  'me sub parled [eos]': 34,
#  'spean duskists sub dorpals sub parls rel pleddist sub clim milturor sub hurperates sa kurched sa humicianeda sa mangere [eos]': 1,
#  'kuestors sub thespirateda [eos]': 2,
#  'bilth ampercials hi skeer penursifers sub calikateda [eos]': 1,
#  'narters sub protter sub flapperated sa nobeda rel visivets sub threak buestors sub onstigipateda sa crailed rel sherician sub zild doloners ob penursifered sa conturize sa engarify rel bunessators ob jobsticatore [eos]': 1,
#  'melottess sub dorpalist sub se ob baniticated sa saunches [eos]': 1,
#  'bo sub tarsed [eos]': 22,
#  'jeethe gangerists sub me ob dupresseda [eos]': 1,
#  'vemeda rel madetors ob duppified rel fantivist sub ghump denaticians sub wanner ob intrinse sa sedundified [eos]': 1,
#  'shrop tibs sub thullamor ob haustisteda [eos]': 1,
#  'breight frominalists sub prask ecoster ob bottiste [eos]': 1,
#  'bo sub purgett humician ob pipistrates sa crails rel wolarist sub ballicizes [eos]': 1,
#  'bellions sub la ob stribere [eos]': 1,
#  'ballicize rel bleckmans sub bilth crotifers ob simpuridate [eos]': 1,
#  'dreek hilldomers sub ghump bolicaters ob enjurify [eos]': 1,
#  'si sub se ob choze [eos]': 4,
#  'la sub hild gumitists ob dafeda [eos]': 1,
#  'drouseman sub stourt ob bunessistes [eos]': 1,
#  'darsh humicians sub tarseda [eos]': 1,
#  'si ob jontifies rel bolitist sub yolves [eos]': 1,
#  'bo sub peaserizes rel trachier ob mespicated [eos]': 1,
#  'bilth fragion ob nulpeneda rel trenners sub inthippenate sa nobs rel gratenist sub streachified [eos]': 1,
#  'wandifieda rel thullamors sub piliciateda rel pilobists ob heferateda [eos]': 1,
#  'scooth blope sub mermillate rel purgettors ob fossicates [eos]': 1,
#  'briticist sub mauces sa unseffed rel ampercial sub chorried [eos]': 1,
#  'povician ob rawned rel rattiner sub allacked [eos]': 1,
#  'baniticians da darsh ballisons sub spean businer ob kippigate rel fumitists ob botticates rel stremorder hi la sub bullif ob mafflitateda sa bule [eos]': 1,
#  'si sub broaleda [eos]': 98,
#  'darsh peagerist sub bullawers sub yerg da spange duskists ob gangeristeda rel theslirists sub si ob thrall sa kurcheda sa fanches [eos]': 1,
#  'bo sub ja ob praimed [eos]': 2,
#  'pi sub la sub shrop botigner ob phoisifieda sa engarified [eos]': 1,
#  'theslirists sub blide lurchists ob povifieda [eos]': 1,
#  'spange drinimat sub melottess sub mermillated sa embarricated [eos]': 1,
#  'ranater sub scoans [eos]': 3,
#  'hild fallengist sub shrop sherician ob mafflicated [eos]': 1,
#  'dutingist sub formantors ob scolterized [eos]': 1,
#  'zild nusts sub madetors sub fantivist sub engaried sa crail sa sedundifieda [eos]': 1,
#  'si ca si sub purgett businers ob grateneda sa engarified rel froacher sub se da la sub bullager ob stickerateda sa thespires [eos]': 1,
#  'elusist sub drinimats sub blide botigner hi bo hi purgett shagoners ob annoriciated rel visivet sub se lu la ma yeige stimpers ob shumpified sa buleda rel wotankers sub me sub jantomizes sa unseff sa formanate rel formantors ob missipate sa buled sa fanch rel tharoners lu noacher sub greanerizes [eos]': 1,
#  'zild wotankers sub mattakate [eos]': 1,
#  'shodderists lu se ma fragion hi bo hi si sub se ob grateneda sa engarifieda rel bolicians sub amackeda rel amackists ob stribere sa formanateda rel fragions da elupizes rel hostician sub trenner sub revalternated sa unseffeda [eos]': 1,
#  'jurb thullamors sub frub gustist sub yawled sa kurcheda rel moldicians sub noachers da si sub plonth formantor ob gangeriste sa pactess sa humicianes rel crotician ob gangeristeda [eos]': 1,
#  'buestors sub wuth justator ob chozed rel tiraster sub unplewed rel bullifist sub denaticians ob frematizes sa saunches sa kurche rel bullifists ob botticateda rel fallengists sub ja sub me sub siverthist sub spange jonters sub me sub inthippenates sa buleda sa lurchifieda rel mafes ob dupressed sa embarricated sa pactesses sa pactesseda rel trenners sub damerticate sa sauncheda sa formanate [eos]': 1,
#  'penessers ob ninged rel melottess ob intrinse rel duskists ob pouteratizes rel humician sub bilth peagerists sub thullamors sub madressize sa sedundifies rel guendor ob intrinseda sa prutifies [eos]': 1,
#  'la sub stremorders sub remiffeda sa mangere [eos]': 1,
#  'gringe denaticians sub la sub si ob bub rel mespicians ob duppify sa unseffeda [eos]': 1,
#  'teeves rel guendor sub wandifies [eos]': 1,
#  'hild gratenists sub la lu la hi smoobs ob enjurify [eos]': 1,
#  'la lu penursifers sub lactissates rel stimper sub tismissates sa engarify [eos]': 1,
#  'ronder sub limbatizes rel ricatite ob gratenized [eos]': 1,
#  'plessickes rel siverthist sub purgett penursifers ob croils [eos]': 1,
#  'la sub smesheda [eos]': 89,
#  'buestors sub streachifieda [eos]': 1,
#  'stoppists sub bo ob midicates rel bullif sub bo ob blitches sa fancheda [eos]': 1,
#  'streck sergator sub elusified rel fossician ob skeezes rel predignor sub bo sub offaldicates sa lurchified sa engarify rel bottists sub bunessisteda sa prutified [eos]': 1,
#  'annoriciate rel ambathers ob tirastizes rel benatician sub revalternated [eos]': 1,
#  'phanicize rel guendors ca bo sub peachicianes [eos]': 1,
#  'si sub ghump povician sub greanerized sa nobeda [eos]': 1,
#  'damerticateda rel lustodists sub yerg wolarists sub greanerize sa strovokicize [eos]': 1,
#  'tharon bullawer sub bo ob gratenized rel crotifer ob draired sa crail rel narters sub wolarifieda rel lustodists ob mespicateda [eos]': 1,
#  'la sub kaidist sub ja ob lustodisted sa sauncheda [eos]': 1,
#  'pi sub streachified [eos]': 43,
#  'elusifies rel jantomer sub la ob thafassizes [eos]': 1,
#  'prask draccont sub purgett businators sub froacher sub dorpalist da madetors sub hild cheldors ob pandicateda sa crins sa sergatize sa formanated [eos]': 1,
#  'damerticates rel gumitist sub burses sub mangerize sa crins sa saunches rel moldician sub doloners lu bo sub spean gloralizer sub si sub remiff sa engarified sa humicianes sa crinned [eos]': 1,
#  'ghump bleckman sub si ob missipated [eos]': 1,
#  'bullawers sub briminates rel striberist sub wainsters sub dorpalists ob rebinkeda sa pactesses sa unseff [eos]': 1,
#  'si sub si ob droverateda [eos]': 2,
#  'pi sub botigners sub skeezeda sa crails [eos]': 1,
#  'ja sub pleddist sub charchs sa nobs [eos]': 1,
#  'frawkess sub ghump frominalist ob droverates [eos]': 1,
#  'stremord cushars sub annoriciate [eos]': 1,
#  'ronders sub ja ob midicateda [eos]': 1,
#  'flingerists sub la ob drol [eos]': 1,
#  'autoners sub breaper sub zurched rel stremorder sub streck penessers sub briminate sa bules sa crail rel tirasters sub gloralizers ob yolveda rel melottesses ob theslirate sa squailed sa nobeda [eos]': 1,
#  'jeethe bottists sub wolarist ob skeezeda [eos]': 1,
#  'la sub rawn [eos]': 81,
#  'fantivists ob engary rel ampercials sub stoppiste rel fallengists sub portify sa squaileda [eos]': 1,
#  'zurches rel rattiner sub froachered [eos]': 1,
#  'elupers sub elupizeda sa humicianed rel formantor sub amackates [eos]': 1,
#  'bo sub frominalers ob traives rel appalate lu enlator ob glucks [eos]': 1,
#  'engaried rel ambather sub se ob pleddisated [eos]': 1,
#  'onstigipates rel stroater sub si ob zurched [eos]': 1,
#  'breight dorpals sub ballicizeda [eos]': 1,
#  'la sub clim trapenist sub pi ob apturicized sa sedundifieda [eos]': 1,
#  'lavoidified rel draccont sub fumit bolicater sub yerg bolicians ob saultified sa bule rel wanners ob missipe rel pilobists ob povicated [eos]': 1,
#  'douch gezziman sub blide briticists ob crotifies [eos]': 1,
#  'dutingists sub yerg fallengist ob stickerateda [eos]': 1,
#  'la sub se ob conveam [eos]': 2,
#  'la ob clummed rel madetor sub stoppisted [eos]': 1,
#  'scupps rel mafe sub dupps [eos]': 1,
#  'stremord strogessor sub dupped [eos]': 1,
#  'spean frominalist ob madetized rel bottist sub streachified [eos]': 1,
#  'horrier sub duskist sub plessicked sa conturizes [eos]': 1,
#  'la sub filkeda [eos]': 114,
#  'se sub bactivitates [eos]': 34,
#  'skame shagoners sub ballicizeda [eos]': 1,
#  'kewardessors sub portifieda sa buleda rel gloralizers sub offaldicateda [eos]': 1,
#  'amberates rel fumitist sub peaserized [eos]': 1,
#  'stremorders sub pi ob lustodiste [eos]': 1,
#  'tirastes rel lenn sub osmissifies [eos]': 1,
#  'blopes sub ja ob gratenize [eos]': 1,
#  'si sub bilth nusts ob damerticate [eos]': 1,
#  'ronders sub douch pilobist ob simpuridate [eos]': 1,
#  'streachifies rel ampercial sub ja ob rawned [eos]': 1,
#  'breight wainsters sub si sub trachiers ob engary sa humicianeda [eos]': 1,
#  'threak gustist sub yolves [eos]': 1,
#  'douch bolitists sub ranaters ob stroveda [eos]': 1,
#  'voncenist sub bo sub frawkesses ob irriticiated sa lurchifies [eos]': 1,
#  'stremord hilldomers sub nust ob rebink rel hosticians sub calinelist ob clummeda sa crin rel prithers sub moldicians ob drause sa mangere [eos]': 1,
#  'kuestors sub gratenizeda [eos]': 1,
#  'streck sergs sub jantomizeda [eos]': 1,
#  'jont duskists sub annoriciate sa mangereda rel amackists ob theslirates rel redullor sub jont pilobists sub naid peagerist sub nestatate rel narters sub dreek lactissist ob zurcheda sa mangered sa mangeres rel visivet ob greanerizeda sa squails sa sedundify rel flingerists ob madetizeda rel guendors sub rattiner sub mofusted sa thespireda [eos]': 1,
#  'wuth naridators sub la ob gumitify [eos]': 1,
#  'mafes sub prither ob slurkeda [eos]': 1,
#  'naid da wuth brelland sub tawlerizes [eos]': 1,
#  'la sub si sub wandifieda sa squaileda [eos]': 2,
#  'wainsters sub jeethe trachiers ob lustodisteda [eos]': 1,
#  'shagoners sub amackists ob dupressify [eos]': 1,
#  'stoppist sub jobsticator sub jont da jont voncenists sub me ob strubdifieda rel buestors sub duskist ob mafflicateda sa mangereda sa prutified sa lurchifies [eos]': 1,
#  'mofustators sub me ob drauses rel purgettor sub jawp bullif ob povified sa mangere [eos]': 1,
#  'scooth moldician sub se sub trachiers sub shagoner sub naid bellions sub vemeda rel trenners ob peagify sa sergatized sa strovokicize sa sedundifies sa sergatized [eos]': 1,
#  'se sub charched [eos]': 38,
#  'voncenist da briticist sub la ma kuestors ob disfrinseda [eos]': 1,
#  'si sub se sub frawkesses ob frains sa thespireda rel madetors sub streck frawkess da la sub thespirated rel trenner sub mofustated sa strovokicize rel cheldors sub me ma si ca gast rel ampercials sub ja ob strubdifieda rel dorpals sub bolicater ob bactivitateda rel midicians ob croicerates rel businator sub elusifies sa crin sa fancheda sa fanches rel gezziman ob dupressifies rel ballison ob blamiciate sa kurche sa crin sa thespireda [eos]': 1,
#  'si sub guend briticist ma zild bolicians ob conveam [eos]': 1,
#  'si sub calin fremators ob missipate [eos]': 1,
#  'streck mofustators sub elupizeda [eos]': 1,
#  'si sub la sub duppified rel botigner ob lustodiste sa embarricate [eos]': 1,
#  'se sub formantor hi amackist lu skeer rattiners sub frub jonters sub peaserizeda sa humiciane sa mangere rel hanes sub darsh humician sub tirastified rel breaper sub phanicized sa formanates rel businator hi si ob mespicated sa prutify sa crins rel burse ob thralled [eos]': 1,
#  'fragion sub briminated [eos]': 2,
#  'hild mafflitist hi stremord gloralizer sub bilth mafes ob engaried [eos]': 1,
#  'douch bolician sub se sub barses sa sergatizes [eos]': 1,
#  'calin flingericians sub tharon gratenists ob wandify [eos]': 1,
#  'nestatate rel brellands sub se ob midicate [eos]': 1,
#  'darsh briticist sub stroves rel povician ob simpuridated [eos]': 1,
#  'briticist sub yeige autoners sub allack sa lurchifies [eos]': 1,
#  'me sub horriers ob gratened [eos]': 1,
#  'jeethe bleckman sub trenner ob stoppisted [eos]': 1,
#  'streck formantor sub mangerizes [eos]': 1,
#  'lactissists sub se sub dargine ob ninged sa pactesseda [eos]': 1,
#  'prottize da calikate rel trapenists sub amberate [eos]': 1,
#  'purgett strogessors sub prausified rel fallengist ob pleddisateda [eos]': 1,
#  'blide mafflitist sub tirastified [eos]': 1,
#  'fusbend mafflitists sub douch bullagers hi rattiner lu scooth purgettors ob tirastizeda [eos]': 1,
#  'damerticated rel bleckman sub calikated [eos]': 1,
#  'hosticians sub benaticianeda [eos]': 1,
#  'peachicianes rel povician sub swarmicated [eos]': 1,
#  'jeethe tharoner sub tismissate rel jobsticators ob clums [eos]': 1,
#  'poutere rel senths sub osmissifieda [eos]': 1,
#  'se sub dreek kewardessors sub mespician sub peachicianeda rel naridators ob zamped sa crinned rel crotician sub blide justators ob pleddisate rel gumitists sub se ob droleda sa humicianes sa prutify sa strovokicizes [eos]': 1,
#  'zild wainsters sub bo sub plessicated sa crinneda [eos]': 1,
#  'ghump gloralizer lu spange ronders sub la ob stribere sa crin rel lustodists sub pleddists ob botticate [eos]': 1,
#  'amackate rel droinists sub portifieda [eos]': 1,
#  'ja sub unplewed [eos]': 37,
#  'parl rel hosticians ma me ob frained rel stourt sub rattiners ob clums [eos]': 1,
#  'flingericians sub la sub pi ob jontifieda sa sergatize [eos]': 1,
#  'rotectifieda rel sergs sub ballisons ca pi sub rolved sa crin [eos]': 1,
#  'wuther sub gasted [eos]': 2,
#  'hule sub trenner ob gratenized [eos]': 1,
#  'si sub tawlerizeda [eos]': 79,
#  'yerg sergator sub ja sub guend mafe ob enjurifies sa thespire rel smoobs ob peagified [eos]': 1,
#  'barsed rel businer sub wanner sub charchs sa engarified [eos]': 1,
#  'frub businers ma banitician sub pi ca lustodist sub yawls sa saunches [eos]': 1,
#  'bo ca si da crotician sub mermillated sa humicianed rel stroater sub si ob clummed sa formanated rel stimper ob drauseda rel amationists sub tharon bolician sub fampenated sa mangere sa unseffs rel bleckman sub si sub rolveda sa fanches [eos]': 1,
#  'thullamor sub me sub bo ob fallengized sa sergatized sa pactess rel ricatites sub ralm [eos]': 1,
#  'hild nestator sub hild da frub ronder ob jobsticatored [eos]': 1,
#  'fusbend bottists sub streachors sub vem sa sedundify [eos]': 1,
#  'stremord gumitists sub zild gezziman ob peagifieda [eos]': 1,
#  'briticist sub bottistes [eos]': 2,
#  'rolved rel amackist sub amackates [eos]': 1,
#  'jobsticators sub miticurizeda [eos]': 2,
#  'gloralizer sub streachifies [eos]': 1,
#  'pi sub la sub amacke sa crins [eos]': 1,
#  'si sub charch [eos]': 71,
#  'zurcheda rel enlators sub wainster sub tirastes sa crail [eos]': 1,
#  'clim cheldor sub la sub stroves rel lustodist sub amackists ob dupressified sa sedundify sa strovokicizes [eos]': 1,
#  'breight siverthist sub enlator ob midicated [eos]': 1,
#  'gringe duskist sub breaper ma naid thullamor ob chutched [eos]': 1,
#  'thrope pleddist sub framitatore rel shericians ob theslirates sa thespired rel voncenist sub gasted sa mangeres rel theslirist sub la sub tharon hostician ob pipistrate sa embarricated [eos]': 1,
#  'smoobs ob bullegates rel gloralizer sub shodderist sub stremorders ob gratenes sa conturized sa humicianes rel mafflitist ob simpuridate rel fusbenders sub threak theslirist ob prockify rel thullamors ob thrall [eos]': 1,
#  'tibs sub ronder ob gangeriste [eos]': 1,
#  'si sub jawp gratenist ob pouteratizeda rel businers ob lavoidify sa formanated rel brelland sub nestators ob enjurified [eos]': 1,
#  'yeige theslirist ob jontified rel naridator sub crotifies [eos]': 1,
#  'threak stourt sub brelland sub gaunch mafes ob likiciates sa embarricate rel drinimats ob tisses rel kuestor ob gangeristes rel siverthist ob croiled [eos]': 1,
#  'wuth bottist sub fallengists ob bubs sa sergatize rel burses sub peaserizes rel ranater ob gangeristeda rel senths sub prask penursifer sub amberates sa formanateda sa crail [eos]': 1,
#  'ja sub tirastified [eos]': 38,
#  'darsh wainster sub ja sub stoppisted sa sergatized sa unseff rel drousemans sub mespician sub prithers sub gloralizers ob saultifieda sa kurches sa saunch [eos]': 1,
#  'sergators sub mofusted rel kuestor ob peagerizeda [eos]': 1,
#  'miticurized rel bolician sub chorries rel trapenist ob draired [eos]': 1,
#  'dake sub hild wainsters ob peagifies [eos]': 1,
#  'si sub prottizeda [eos]': 78,
#  'hilldomers sub bleckman sub bo sub se sub duppist ob shumpifies sa crails sa crins sa prutifieda [eos]': 1,
#  'scupps rel penursifer hi calin noacher ob povifies rel lustodist sub striberated [eos]': 1,
#  'la sub peagerists sub stroveda rel drinimats ob dupressifieda rel pactesses ca me ob pouteratize sa sergatizeda [eos]': 1,
#  'breapers sub voncenists sub charch sa formanate [eos]': 1,
#  'guendor sub thrope dutingist sub fusilitated sa bules [eos]': 1,
#  'hilldomer sub ambathers sub ampercial sub thrubs sa saunches rel mofustator ob ningeda sa sedundified [eos]': 1,
#  'theslirist sub povicated sa lurchifieda rel duppists sub shagoners ob prockify [eos]': 1,
#  'allackeda rel bullagers sub kaidists sub tharon briticist ob jontifieda sa buleda rel crotifers hi fragions sub chorrieda sa fanches rel fossician ob gluck sa embarricates rel buestor sub excribits [eos]': 1,
#  'la sub piliciateda [eos]': 75,
#  'trenner sub fusbend bellion ob bolicizeda rel denaticians sub bunessisteda sa crinneda rel croticians sub businators sub peachiciane sa mangere sa crinned [eos]': 1,
#  'blide lustodists sub si ob strove [eos]': 1,
#  'si sub mermillateda [eos]': 108,
#  'horrier ob jeapeda rel bolicaters sub hild blopes ob sosk [eos]': 1,
#  'hanes ob botticated rel burse sub prottizes [eos]': 1,
#  'tharon dorpalists sub pi sub elusifies sa strovokicize rel moldicians ob annoriciate [eos]': 1,
#  'briticists sub jawp flingerists sub portifieda sa prutifieda [eos]': 1,
#  'stoppists sub ja ob frematizeda [eos]': 1,
#  'purgett gumitists sub spange ecosters ob pleddisate [eos]': 1,
#  'fampenate rel melottesses sub mafflitist ob thralleda rel fragions ob visify [eos]': 1,
#  'skame trachiers sub denatician ob skeez [eos]': 1,
#  'si sub bunessiste [eos]': 82,
#  'striberateda rel gloralizers sub jont briticists ob slurkeda sa engarify rel fantivists sub peagerizeda [eos]': 1,
#  'cushar sub mofustates rel gratenist ob irriticiated [eos]': 1,
#  'stourts sub naid voncenists sub thullamizeda sa unseffeda [eos]': 1,
#  'charcheda rel bolitists sub kaidist ob pleddisateda [eos]': 1,
#  'si sub jeethe kewardessors sub portify sa craileda [eos]': 1,
#  'si sub se ob skeezeda [eos]': 2,
#  'visivets sub meech moldicians ob dafe rel shagoners sub spean wolarist ob zurch sa sergatize [eos]': 1,
#  'predignors sub bo ob conveam [eos]': 1,
#  'se ca froacher sub duppist ob strozed rel bullif sub broaled sa fanched [eos]': 1,
#  'si sub protters ob droleda sa formanate rel fusbenders sub bilth kuestors hi se ca blope sub hilldomers sub forigate sa bules sa conturize rel ricatites sub treaves rel horrier ob frematizeda sa mangereda rel hilldomers ma meech dorpalists sub striberateda sa sedundifieda [eos]': 1,
#  'si sub wuth dake ob baniticate [eos]': 1,
#  'gratenize rel amationists sub ghump theslirists sub denaticate sa strovokicizeda [eos]': 1,
#  'la sub offalde [eos]': 62,
#  'me sub pi sub jont bellion ob yosses sa conturizes sa formanateda rel rattiners sub clim redullors sub wotanker ob penursifereda sa crinneda [eos]': 1,
#  'tharon mafflitists sub yeige buestors ob visifies rel moldician ob draireda [eos]': 1,
#  'botig smoob ob ning rel dorpalists hi si ob scolterizeda rel appalates ca se sub povicians sub bilth froachers ob clum sa crins [eos]': 1,
#  'crene formantors sub rawneda [eos]': 1,
#  'se sub tawlerized sa humicianed rel dargine sub hosticians da la ob croils sa squails rel stremorder sub clim melottesses ob mafflicates [eos]': 1,
#  'fumit smoob sub si sub mofuste sa saunches [eos]': 1,
#  'tharon strogessors sub si ob simpuridateda [eos]': 1,
#  'ambathers sub streck botigner ob peagerize [eos]': 1,
#  'revalternates rel trachier sub la ob maffliced [eos]': 1,
#  'guend nusts sub yolve [eos]': 1,
#  'si sub povicates rel kaidist ob visifieda [eos]': 1,
#  'saffle rel lustodists sub scooth kewardessor sub si sub zurcheda sa sergatizes sa engarifieda [eos]': 1,
#  'si sub la ob dafe sa formanate rel thullamors sub stoppist ob yosseda [eos]': 1,
#  'bo sub melottesses sub barse sa embarricates [eos]': 1,
#  'gringe briticists sub penessers ob bactivitate [eos]': 1,
#  'si sub lavoidify [eos]': 75,
#  'visifieda rel amationists sub scoaneda [eos]': 1,
#  'bactivitor sub piliciates [eos]': 2,
#  'si sub pi ob fallengizes rel povician ob stickerate [eos]': 1,
#  'baniticians ob joofed rel streachor sub se ob yossed rel stroater ob gratenes [eos]': 1,
#  'trapenist sub fumit predignor sub la sub thrubbeda sa buled sa kurched [eos]': 1,
#  'filkeda rel bolitists sub mattakateda [eos]': 1,
#  'hanes sub engary [eos]': 3,
#  'plonth dutingists ob bullegateda rel naridators sub tharon sergs ob zurch [eos]': 1,
#  'crotifers sub peaserize [eos]': 2,
#  'briticists sub purgettor ob mafflitate [eos]': 1,
#  'pi sub broaled rel peagerist sub portifies sa prutified sa formanateda rel ranaters sub si hi stimpers sub purgett bottists sub la sub me ob wandify sa unseffeda sa prutifies rel fantivist sub si sub shagoners sub mespicians ob dafeda sa humicianeda sa strovokicized sa sergatize sa engarify [eos]': 1,
#  'ghump bolitists sub mueda [eos]': 1,
#  'spean ambathers sub limbatizeda [eos]': 1,
#  'protter sub douch lustodists ob phonorizes rel pactesse ob bunessisted rel siverthist sub plessicates sa sedundifies [eos]': 1,
#  'la sub si ma engary rel duppists ob justatore [eos]': 1,
#  'bullifist ob theslirateda rel bolitists sub limbatize [eos]': 1,
#  'fallengist ob enjurifieda rel lactimers ob bunessistes rel stimper sub streachifies [eos]': 1,
#  'calin dutingists sub si ob thafassize sa squaileda rel guendors sub plonth peachicians ob nulpeneda [eos]': 1,
#  'ghump froacher sub bilth bullifs sub breight hilldomer sub apturicizes sa fanch sa prutifies [eos]': 1,
#  'si sub remiffeda [eos]': 78,
#  'se sub offaldicates [eos]': 46,
#  'bo sub bullawers ob nings [eos]': 1,
#  'rawn rel shodderists sub pi sub hilldomers da la sub ambathers ob slurkeda sa strovokicized sa squaileda [eos]': 1,
#  'la sub la ob pouteratizeda [eos]': 7,
#  'jobsticators sub treaved rel ampercial sub crene redullors sub si sub yeige droinists ob bolicizeda rel siverthists ob greanerized rel hostician sub strogessor sub bo ob shumpifies sa prutifies sa prutify sa unseffs rel kaidist ob blarp sa crinned sa pactessed rel denatician sub mued sa kurcheda [eos]': 1,
#  'shagoners sub nestatate [eos]': 4,
#  'jonters sub si sub tawlerizeda sa humicianeda [eos]': 1,
#  'fusbend redullors sub wotanker sub rotectifies sa sauncheda [eos]': 1,
#  'melottesses sub shrop stroaters sub parl sa kurcheda [eos]': 1,
#  'bo sub bolitists sub elusify sa crinneda rel breapers ob dafed [eos]': 1,
#  'bottists ca la da lurchist sub gumitist ob droverateda [eos]': 1,
#  'jonter sub fusbend fantivist sub elupizes sa saunched sa sedundifieda rel horriers da businator ob gratene rel businers sub osmissifieda rel noachers ob yosseda [eos]': 1,
#  'threak povicians ob spooled rel kuestor sub si sub povicateda sa pactessed [eos]': 1,
#  'bilth da calin milturors sub fantivist ob zurcheda [eos]': 1,
#  'si sub pi sub hostician ob bullegated sa lurchified rel cheldor sub ghump bunessator sub bellions sub purgett bleckmans ob intrinse sa conturizeda rel jobsticators sub ghump fossician ob phonorize sa crails rel predignor ob povicated sa crinned sa thespire [eos]': 1,
#  'la lu ja da gangerist sub streck trenner ob heferate [eos]': 1,
#  'horrier lu threak pleddists ob stribered rel briticist sub vem rel sergs sub offaldicateda rel humicians ob chozeda sa crailed rel nestator ob traives [eos]': 1,
#  'horriers sub si sub la sub se sub dreek mespician ob blitched sa fanches rel nust sub scupps sa kurche sa kurche sa conturize [eos]': 1,
#  'me sub spange gangerists ob tirastized [eos]': 1,
#  'meech mafe sub hurperates [eos]': 1,
#  'stoppisted rel ampercial sub plonth benatician ob fossicates [eos]': 1,
#  'botig stimper sub remiffed rel ballison ob jobsticatores [eos]': 1,
#  'stremord stimpers sub maksizeda [eos]': 1,
#  'bunessiste rel hules sub ricatite ob pleddisateda [eos]': 1,
#  'pi sub guendor ob theslirates rel amationist sub bactivitated sa pactesses [eos]': 1,
#  'douch breaper sub doloners ob dupressifies [eos]': 1,
#  'fusbend draccont sub bactivitates [eos]': 1,
#  'duppists sub povicians ob blitcheda [eos]': 1,
#  'prottizes rel madetor sub prausifieda rel fusbenders sub fusilitateda rel autoners ob povicates rel dorpalist ob sosk sa pactessed sa prutified rel brelland sub la sub maksize sa fanches [eos]': 1,
#  'kuestor sub ballicized [eos]': 2,
#  'gezzimans sub amberateda [eos]': 1,
#  'bottiste rel lurchists sub tawlerize sa embarricate rel prithers sub si ob damerticateda [eos]': 1,
#  'yeige framitator sub la ob chutched [eos]': 1,
#  'se sub calin stourt sub thullamor sub striberates sa pactessed sa squails [eos]': 1,
#  'si lu formantor hi tharon lactimer sub peaserizes [eos]': 1,
#  'me sub nestatates [eos]': 30,
#  'me sub thullamized [eos]': 32,
#  'gast rel strogessors sub autoner sub intrinsed sa engarifieda [eos]': 1,
#  'thrubs rel drouseman sub striberate rel lustodists ob madetizes sa sergatized rel streachor sub stremord da jawp trenner ob penursifered sa unseffed rel jobsticator ob zurch rel thullamors hi la sub streachifies rel strogessor ob skeezeda [eos]': 1,
#  'se sub purgett shagoner ob justatored [eos]': 1,
#  'formantors sub se ob jontify rel baniticians ob midicateda [eos]': 1,
#  'me sub calikates [eos]': 36,
#  'skame burse sub scooth bolitists sub framitatoreda sa conturizes [eos]': 1,
#  'ambathers sub excribit [eos]': 2,
#  'chorrieda rel droinists sub onstigipate [eos]': 1,
#  'shrop dakes ob praim rel duppists sub haustist sub si ma pi sub offaldicates sa sergatizes sa squaileda [eos]': 1,
#  'la ob simpuridated rel briticist sub briticists sub darsh shodderist sub stremord frominalers ob midicated sa fancheda sa embarricates rel povician ob maffliceda rel humicians ob spooled rel ecoster sub narter sub greanerizes sa mangered sa conturized [eos]': 1,
#  'jeethe burse sub mued [eos]': 1,
#  'miticurize rel framitators sub fusbend briticists ob bub [eos]': 1,
#  'blide dargines sub sturk [eos]': 1,
#  'redullor sub jawp dutingist sub wandified sa squail rel bleckmans ob gratenizes [eos]': 1,
#  'purgett da jawp nestators sub dorpalist ob gumitifieda [eos]': 1,
#  'pleddists sub rawneda [eos]': 2,
#  'pi sub fusilitateda rel fremators ob gratened sa thespired rel wotanker sub denatician sub stoppisteda rel frominalists sub clim sherician ob wandify sa prutified sa kurche rel fremators sub jurb burses sub portify sa prutify sa embarricated [eos]': 1,
#  'fusbend botigner sub bullawers ob mafflicated [eos]': 1,
#  'cheldor ob praim rel bullifs sub ja sub annoriciates sa embarricateda [eos]': 1,
#  'naid midicians ob praimeda rel kuestors sub fusbend thullamor sub me sub hild brelland sub streck theslirists sub parl sa mangereda rel prithers sub si sub thrombicized rel lactimer ob botticateda sa pactesseda sa prutifies sa engarified sa humicianed sa nob [eos]': 1,
#  'yeige pilobists sub bottists sub bactivitateda sa crin [eos]': 1,
#  'burses sub si sub bullagers ob enjurifieda sa engarify [eos]': 1,
#  'mofustator sub hurperate rel kewardessors ob draired [eos]': 1,
#  'la sub nust ob tirastify rel gangerists ob gangeristeda [eos]': 1,
#  'breight justators sub skeezeda [eos]': 1,
#  'jurb lustodists sub duppify [eos]': 1,
#  'duppified rel fantivist ob phonorize rel prithers sub vem [eos]': 1,
#  'businator ob pipistrates rel enlator sub parls [eos]': 1,
#  'guend botigners sub la ma la sub calikate sa crin rel fumitists ca jawp wanner ma plonth da yeige trachier ob povicateda [eos]': 1,
#  'jont hule ob yolves rel prither sub siverthists sub stimper ob droverateda sa prutified [eos]': 1,
#  'fumit dracconts sub onstigipateda rel businers ob scolterizeda [eos]': 1,
#  'guend trapenists sub ghump ranater sub bo sub stremord peachician ob stickerateda rel justators sub clim bullifs ob stribereda sa mangered sa unseffs sa kurcheda [eos]': 1,
#  'calin hule sub pilobist ob croicerates rel crotician sub threak fragion sub bo sub plonth lustodist sub banitician ob bullegates sa humicianed sa sergatizes sa mangered sa crails [eos]': 1,
#  'se sub chorry rel elupers hi la ob enjurify rel senths sub yolve sa mangeres [eos]': 1,
#  'skeezeda rel wolarists sub remiff [eos]': 1,
#  'se sub bilth bactivitors ob praimed [eos]': 1,
#  'tarseda rel wuthers ob bolicized rel drouseman ob thafassizeda rel strogessors sub povicate [eos]': 1,
#  'douch kuestors da bellion sub stoppisteda [eos]': 1,
#  'purgett da fumit denatician sub gratenizes [eos]': 1,
#  'frub ricatites sub maksizeda [eos]': 1,
#  'se sub tirastified sa formanated rel businer sub penessers sub noachateda sa sergatized sa embarricate rel cushars sub si ob bullegate [eos]': 1,
#  'bo sub mangerizes rel buestor da la ob dafed [eos]': 1,
#  'guendor sub peaserized [eos]': 4,
#  'flingerists sub se sub rolved sa bule sa kurcheda rel frawkesses ob conveam rel flingericians sub siverthist lu forigates rel hilldomer sub purgett hostist sub ghump stroaters ob stickerated sa engarifies sa buled rel serg ob bactivitate [eos]': 1,
#  'naridators sub nestatate [eos]': 3,
#  'brelland sub me ob tirastifies [eos]': 1,
#  'pi ob irriticiated rel fragion sub la ob kuestified [eos]': 1,
#  'la sub bo sub ronder ob prockified sa squaileda [eos]': 1,
#  'lenns sub darsh striberist ob droled rel pleddist ob phoisifieda [eos]': 1,
#  'tirasters sub me ob clummed rel ronder sub me ob midicated sa craileda rel sergs sub zild brellands ob scolterize sa humiciane [eos]': 1,
#  'plonth flingerist sub naid povician sub burse sub gratenized sa conturized sa mangeres [eos]': 1,
#  'la sub spean shodderists ob heferate sa pactess rel gangerists sub mangerize [eos]': 1,
#  'scooth lactissists sub plessickeda [eos]': 1,
#  'shodderist sub skame lactimer sub rolves sa unseffs [eos]': 1,
#  'siverthists sub si sub shrop senths ma la sub elupized rel bleckman ob pandicate sa sergatizeda rel frominalers ma jont frominalist sub ballicized sa pactess sa sauncheda [eos]': 1,
#  'fallengists sub gangerists sub fumit prither ob skeezeda sa thespire [eos]': 1,
#  'si sub kewardessor ob gratenize sa formanate rel senths sub bo sub plessickes sa sergatizeda [eos]': 1,
#  'peagerist sub formantors ob bubbeda rel smoobs sub peachicianeda sa embarricates [eos]': 1,
#  'ghump fossician sub clim smoobs sub gringe trenners sub phanicizeda sa strovokicizeda sa unseffed [eos]': 1,
#  'me sub si hi bilth formantors da crene moldician ca darsh ranaters ob visified [eos]': 1,
#  'jurb banitician ob enjurify rel bottists sub thespirate [eos]': 1,
#  'mespician sub predignor ob pandicated rel calinelist ob zurched [eos]': 1,
#  'rattiner sub ja sub si sub lurchify sa sergatizes sa kurched rel serg ob mafflicates [eos]': 1,
#  'bo sub autoners ob baniticated [eos]': 1,
#  'la sub pi sub predignors sub benaticianes rel framitator ob phoisifies rel senth sub elupizes sa sauncheda sa crails sa unseffed rel wanner ob joofeda [eos]': 1,
#  'scooth blopes sub la ob mespicate [eos]': 1,
#  'ja sub fampenates [eos]': 29,
#  'me sub thullamors sub penesser ob dafed rel bullifist sub filked sa conturizes rel smoob sub jantomizes rel flingerist sub piliciated sa prutifies sa strovokicize sa engarifies sa strovokicizeda rel pleddists sub zild amationist sub streck milturors sub stremord da threak amationist sub smeshs sa squaileda sa crins sa formanateda sa saunch rel thullicians sub clim ranaters sub purgett elusist sub striberated sa bule rel buestors sub streck wuther ob lawticianeda sa sergatize sa mangereda [eos]': 1,
#  'dolonician sub apturicizes [eos]': 3,
#  'bo sub allacked [eos]': 30,
#  'trachiers ob justatoreda rel hosticians sub annoriciate [eos]': 1,
#  'naid blopes sub lenns ob gumitifieda [eos]': 1,
#  'me da moldicians ob kuestifieda rel gangerists sub noachate [eos]': 1,
#  'bo sub dupped [eos]': 36,
#  'si ob simpuridates rel burse sub si sub inthippenateda sa conturizes [eos]': 1,
#  'skeer nestator sub gringe gustists ob mespicates [eos]': 1,
#  'streachors sub amackists ob drauseda rel formantors sub si ob rebink sa lurchify [eos]': 1,
#  'bo sub miticurizes [eos]': 45,
#  'lurchists sub si sub tiraster sub ghump justators ob zurches sa buleda sa kurcheda [eos]': 1,
#  'croticians sub streck stremorders sub dolonician ma threak mofustator sub autoner sub spange bullif ob gratenizes sa squailed sa strovokicize sa formanate rel dorpals ob wandify [eos]': 1,
#  'la sub guendor sub phanicized sa bule [eos]': 1,
#  'la sub offaldicateda rel cheldors ob joof [eos]': 1,
#  'thrombicized rel ronder sub ja sub la sub streachifies rel gumitist sub bo sub ja sub stroved sa pactessed sa nob rel tharoners sub chorrieda sa kurches sa unseffeda rel jantomers ob drairs rel kewardessor sub thespirates sa engarify sa sedundified rel purgettor sub mofustated sa mangered sa sergatizes [eos]': 1,
#  'pi sub la ob disfrinses [eos]': 4,
#  'strogessor sub calin gratenist ob lavoidified [eos]': 1,
#  'scooth elusist sub froachered sa fanches rel striberist sub forigates [eos]': 1,
#  'milturor sub saffled rel drouseman sub ja sub cheldor ob povifies sa nobs sa humicianed [eos]': 1,
#  'wog rel penursifers sub jantomizeda [eos]': 1,
#  'streachor sub fusbenders sub lavoidify sa fanches [eos]': 1,
#  'prask kewardessor sub peachicianed rel dargine sub justators ob blarps sa prutifies [eos]': 1,
#  'bo sub si sub teeve sa crins [eos]': 1,
#  'stremord ranaters sub la ob stoppisteda [eos]': 1,
#  'la ca botig frawkess sub se ob apturicizes sa nobs rel bleckman sub plessicates rel senth lu zild bottist sub frawkess sub intrinsed sa humicianes sa mangered [eos]': 1,
#  'jawp dracconts sub gaunch stourt hi si sub gast sa conturizeda rel striberists ob tisse [eos]': 1,
#  'yeige visivet sub jantomized [eos]': 1,
#  'si sub se sub filked sa humiciane [eos]': 1,
#  'miticurizeda rel hules sub pi ob mafflice [eos]': 1,
#  'me sub la ob slurked sa conturizes rel peachician sub thrope naridator sub hild stoppist ob jeaps sa conturizes [eos]': 1,
#  'skeer justator lu mofuste rel elusists ob frematizeda rel lenns sub gringe droinist ob penursiferes rel mespician sub fusilitated sa fanched rel striberist sub crotified sa formanateda [eos]': 1,
#  'breight prithers sub fusilitated rel lurchist ob annoriciateda [eos]': 1,
#  'ballisons sub nestatateda [eos]': 3,
#  'naid jantomers sub skeer moldicians ob bullegate rel peachicians sub revalternateda sa fancheda [eos]': 1,
#  'purgett duppists sub mauce [eos]': 1,
#  'tawlerized rel jonter sub streck dutingist sub stourts sub businator sub gumitist ob povifies sa crinneda sa thespires sa prutifies [eos]': 1,
#  'autoners sub bullif ob bolicized rel humician lu la ob frain rel blopes sub me sub rolved sa conturizeda sa thespire [eos]': 1,
#  'stroves rel kewardessor sub tiraster sub mues sa sergatizes [eos]': 1,
#  'theslirist sub stourt sub onstigipates sa squaileda rel brellands sub benatician sub naridator ob glucked sa nobeda sa conturized [eos]': 1,
#  'wuth peachicians sub peaserize [eos]': 1,
#  'la sub yawl [eos]': 83,
#  'pi sub la ob crotifies [eos]': 1,
#  'bo sub maksizeda rel briticists sub dracconts ob dupresseda sa saunched [eos]': 1,
#  'wuth dakes ma si sub smesheda [eos]': 1,
#  'allacks rel haustist sub protter sub pi ob nings sa kurches [eos]': 1,
#  'la sub se sub tharon droinists lu osmissifies rel wotanker sub offaldes sa formanated rel voncenist ma pi ob midicates sa formanate [eos]': 1,
#  'thrope hule sub amackate rel frawkesses ob damerticated [eos]': 1,
#  'bullawers sub serds ob enjurifieda [eos]': 1,
#  'purgett kaidist sub teeves [eos]': 1,
#  'si sub benaticiane [eos]': 77,
#  'plonth eluper sub ja ob croicerated rel ronder ob stoppistes [eos]': 1,
#  'justators sub rolve [eos]': 1,
#  'strogessor ob lustodiste rel trapenists sub froacher sub bo ca si ob gangeristed sa sergatizeda sa crins rel dolonician sub spean strogessors ob jeapeda rel flingericians sub thullamizeda sa conturized [eos]': 1,
#  'bactivitor sub spean peagerists sub limbatizeda sa unseffed sa lurchifies rel froacher sub yerg duskists ob thafassized [eos]': 1,
#  'spange kuestor sub thrombicized [eos]': 1,
#  'la sub garf rel stimpers ob pouteratizeda [eos]': 1,
#  'se sub peachicians ob stroveda rel serds sub la sub amackates rel eluper sub guendors sub la sub croticians ma crene wotanker ob scolterizeda sa sedundifieda sa saunched sa pactess rel stourts sub gaunch visivets sub rolveda sa lurchifieda sa humiciane sa nob sa embarricates sa sauncheda rel elupers sub briticist sub yeige lenns ob strove rel dorpalists ob croils sa nobeda sa crinneda rel striberists sub bo ca stroaters lu fusilitated rel sherician ob dupresse [eos]': 1,
#  'shagoner sub peachicianed [eos]': 5,
#  'skeer froacher da tharoner ob peagerizes rel wanner sub bullif lu enlators ob bactivitates [eos]': 1,
#  'briticist ob dupressified rel duskist sub bottisted sa formanated rel dorpal sub peagerized [eos]': 1,
#  'prask redullors sub gratenize [eos]': 1,
#  'breight hostists sub allack [eos]': 1,
#  'wolarifieda rel bullifists sub pi sub rotectified sa unseff [eos]': 1,
#  'ja ob annoriciates rel hostist ob stribered rel fossician sub yawls [eos]': 1,
#  'wuth dorpalists sub humicians ob frematize [eos]': 1,
#  'darsh mafflitists sub zurcheda [eos]': 1,
#  'fumit briticists sub si sub dracconts sub calinelist ob maffliceda sa formanateda sa buleda [eos]': 1,
#  'la sub la ob tirastify [eos]': 4,
#  'bunessisted rel pleddist sub la ob baniticates [eos]': 1,
#  'froacheres rel shagoner sub elupized [eos]': 1,
#  'breight mofustators sub wuther sub si sub clim dracconts sub bolicaters sub vemeda sa embarricateda sa sedundifieda sa humicianed sa lurchify [eos]': 1,
#  'wotankers sub tharon shagoner ob clummeda [eos]': 1,
#  'saffled rel fossician sub breight serd sub flapperates sa strovokicized [eos]': 1,
#  'la sub mafflitists sub bo sub briticists sub strogessors sub maksize sa sauncheda sa squailed sa thespire sa squail sa fanches rel mafe sub thullicians ob mafflicateda rel striberists sub fremator ob rebink sa fanched [eos]': 1,
#  'moldicians sub stroaters hi si ob thafassizes rel crotifer hi plonth burses sub duskists sub crene fusbender ob jobsticatoreda sa craileda sa lurchify [eos]': 1,
#  'yeige formantor sub me ob scolterized [eos]': 1,
#  'mafes sub prausify [eos]': 3,
#  'pi ob zurcheda rel gumitists sub me sub yawled sa formanated rel bellion sub se ob peagerized sa thespire sa kurche rel rattiners sub smesheda [eos]': 1,
#  'si sub allackeda [eos]': 79,
#  'dolonician sub jawp lustodists ob jontifies [eos]': 1,
#  'naid stimper sub barses [eos]': 1,
#  'streck bleckman sub scupps [eos]': 1,
#  'elusist sub scooth penesser ob clums [eos]': 1,
#  'se sub annoriciates [eos]': 37,
#  'threak fragions sub spange noacher ob bubbeda [eos]': 1,
#  'pi sub si ob pipistrated rel lenn sub elupized sa strovokicizes [eos]': 1,
#  'pi sub denaticians sub zild da calin businator ob pleddisateda sa squails [eos]': 1,
#  'amberates rel gustist ob lustodiste rel jantomers lu scooth draccont ob bubbed rel fragion sub lurchifies [eos]': 1,
#  'la ca plonth wotankers ob croicerated rel lurchist sub parled [eos]': 1,
#  'tib sub se sub la ob peagerized sa embarricated [eos]': 1,
#  'spean dracconts sub la sub charcheda sa mangere [eos]': 1,
#  'spean fantivist ob justatored rel justator sub naid guendor sub damerticated sa sergatized [eos]': 1,
#  'la ob clum rel bullifs sub revalternate sa conturizes rel purgettor sub hostists sub sturkeda sa engarified [eos]': 1,
#  'offaldicateda rel framitators sub bilth lustodists sub maksizeda rel ampercials ob stoppiste sa mangereda sa formanate rel crotifers sub poutereda [eos]': 1,
#  'stimpers sub guend trapenist sub me ob botticated sa thespires rel wotanker sub rolves sa embarricate [eos]': 1,
#  'denatician sub pi ca si ob croileda rel shericians ob greanerizeda rel elusists sub spean serd ob likiciateda sa formanates rel wolarist sub se sub bolician sub skeer bottists sub stimpers sub streck kuestors ob gratenize sa formanateda rel flingerists ob poutereda sa crailed sa crailed rel tib sub nestators sub spange framitator ob jeaps rel amackist ob ningeda sa lurchified sa thespires sa sedundified sa nobeda rel briticists ma bo sub skeer businator sub maksizes sa engarifies sa embarricated [eos]': 1,
#  'crene wolarists sub barseda [eos]': 1,
#  'blide horrier sub wogs rel cheldor ma skeer mafes ob glucked [eos]': 1,
#  'tarsed rel lustodist ob greanerizeda rel gustists sub unplew [eos]': 1,
#  'baniticians sub wuth businer ob slurkeda [eos]': 1,
#  'ghump stroater ob missiped rel dorpal ob croiled rel hane sub visified [eos]': 1,
#  'douch ricatites sub amackeda [eos]': 1,
#  'la sub stimpers sub plonth cushars ob gumitify sa kurched rel elusist ob pleddisate [eos]': 1,
#  'damerticateda rel trachiers sub apturicize [eos]': 1,
#  'fumit bactivitor sub inthippenated [eos]': 1,
#  'jont gloralizer sub si sub tharon flingerists sub engary sa sergatizeda sa mangered [eos]': 1,
#  'shodderists sub yeige eluper sub visifies sa sauncheda [eos]': 1,
#  'botig crotician sub scupps [eos]': 1,
#  'drinimats sub amberateda [eos]': 1,
#  'streck ranater sub trachiers ob jontifies [eos]': 1,
#  'guend gangerist sub garfs [eos]': 1,
#  'yerg stourts sub gaunch penessers sub chorrieda sa fancheda [eos]': 1,
#  'melottesses sub la ob drair sa engarifies rel bullifist sub thrub rel dolonicians sub flapperate sa engarified [eos]': 1,
#  'dake ob rawns rel shagoner sub lurchifies [eos]': 1,
#  'tib sub gaunch hanes ob shumpified [eos]': 1,
#  'wandify rel botigners sub striberateda [eos]': 1,
#  'streck stoppists sub pi sub pi sub bo sub se ob traives sa pactesses sa strovokicizeda rel lenns hi haustists sub guend burse ob zurch rel dargines ob peagified rel predignor ob zurcheda sa squails sa conturize [eos]': 1,
#  'pi sub siverthists sub amberate sa kurches [eos]': 1,
#  'bunessator sub offalded [eos]': 2,
#  'serg sub greanerizes [eos]': 2,
#  'visivet sub pi ob pouteratized [eos]': 1,
#  'si sub dorpal sub gasts sa pactessed rel blope lu ja ob enjurifieda sa thespireda rel tirasters sub spean pactesses ob thafassizeda [eos]': 1,
#  'cushars sub blope sub tarses rel appalate sub midicians sub yolve sa humicianed sa conturizes sa engarify [eos]': 1,
#  'wotankers sub thrope haustist sub stimpers sub bellions sub jeethe amationists ob kippigateda rel mafflitists sub si sub striberateda sa embarricate sa formanate rel ambathers sub se ob gratenize sa formanateda sa pactesseda sa crins sa prutifieda [eos]': 1,
#  'si sub mattakate [eos]': 80,
#  'bo sub hurperates [eos]': 48,
#  'hurperates rel crotician sub threak dakes ob zamps [eos]': 1,
#  'la sub la ob duppify [eos]': 4,
#  'si sub mofustate rel framitators ob yosseda [eos]': 1,
#  'mafe sub madressizes [eos]': 2,
#  'pi sub parls [eos]': 33,
#  'tharoners sub tarse [eos]': 1,
#  'fusilitates rel benatician sub pi ob bottistes [eos]': 1,
#  'la sub la sub midicians ob rawn sa sergatize rel bolitists ob maffliceda [eos]': 1,
#  'la sub amackist ob greanerizeda [eos]': 1,
#  'crene serg sub fremator sub la ob apturicized sa fanches rel lenn sub bunessator sub gringe gumitists sub thullamors ma jonter ob botticateda sa buled rel penursifer ob bubs sa buled sa conturizeda rel penessers sub gustists ob spooleda sa mangeres [eos]': 1,
#  'meech pleddists sub thullamizeda [eos]': 2,
#  'clim jobsticator sub calikates [eos]': 1,
#  'wanners sub peachicianeda [eos]': 2,
#  'pi sub onstigipates [eos]': 42,
#  'bolitists sub spean lactimers sub jonter ob engarieda sa engarifieda [eos]': 1,
#  'fusbend milturor sub doloner sub serd sub benaticianes sa strovokicize rel bunessators sub excribit rel wolarists ob povicate sa conturizes sa strovokicizes [eos]': 1,
#  'threak buestor sub si ob heferated [eos]': 1,
#  'guend guendor sub si sub mofustate sa sergatizes [eos]': 1,
#  'theslirists sub la sub spean buestors sub si ob blamiciate sa conturize sa conturize [eos]': 1,
#  'si sub thrope predignors ob theslirateda [eos]': 1,
#  'bolician sub la ob peagified sa strovokicize rel breapers sub tirastifieda [eos]': 1,
#  'teeveda rel brellands ma formantors sub drinimat sub streachor da protters ob lustodisteda rel bolicaters ob garfs sa squaileda [eos]': 1,
#  'pi sub jont draccont ob justatored [eos]': 1,
#  'noachers sub povicate [eos]': 2,
#  'jurb jonter ob yossed rel frominalist sub la ca tharoners ob yosses [eos]': 1,
#  'redullors ob bub rel breapers sub hane sub tirastifies sa conturize [eos]': 1,
#  'darsh elusists sub offalde [eos]': 1,
#  'filk rel stremorders sub offaldes rel serd ob rebink [eos]': 1,
#  'stremorder sub se sub me ob missipates sa saunched [eos]': 1,
#  'hostists sub jeethe pactesse sub lactimers sub crene frominaler ca meech mafflitist ob baniticate sa embarricated sa strovokicize [eos]': 1,
#  'la sub engarieda [eos]': 88,
#  'si sub engarieda [eos]': 83,
#  'fossicians sub breaper ob pleddisateda rel hostists ob conveam [eos]': 1,
#  'bo sub drinimats sub la sub pi ob tirastifieda sa humicianeda sa humicianed [eos]': 1,
#  'tirastified rel kaidist sub purgett prithers ob lustodistes [eos]': 1,
#  'si sub ja ob thralleda [eos]': 2,
#  'hosticians ob rawned rel enlator sub crene stimper ob maffliced [eos]': 1,
#  'jobsticator sub fantivist ob dupressed [eos]': 1,
#  'serds sub ralm [eos]': 3,
#  'prask prither sub wolarified [eos]': 1,
#  'ja sub bo ob dafed [eos]': 2,
#  'la sub streachify [eos]': 92,
#  'businator sub prask drinimats ob blarps [eos]': 1,
#  'si ob theslirates rel mespician sub thrope cushar ob annoriciates [eos]': 1,
#  'la sub offaldicate [eos]': 83,
#  'la sub se sub gasts sa fanch rel protters ob shumpify [eos]': 1,
#  'bactivitors sub crene mofustator sub purgett trapenists sub bullifist ob jobsticatore sa embarricated sa conturize [eos]': 1,
#  'excribited rel streachor sub si da si ob duppified [eos]': 1,
#  'flapperateda rel blopes sub si ob shumpifieda [eos]': 1,
#  'se sub bolitist ob damerticates [eos]': 1,
#  'gustists sub rattiner ob chutch [eos]': 1,
#  'blide redullors sub bo ob poutere [eos]': 1,
#  'wainster sub gaunch denatician sub protters ob fraineda rel flingerists ob enjurified sa crins [eos]': 1,
#  'thrope crotician sub mofustates [eos]': 1,
#  'scooth povician sub shrop bolitist ob rawned [eos]': 1,
#  'la sub gumitist sub naid drinimat sub unplewed sa thespires sa sedundifieda [eos]': 1,
#  'frub crotifer sub gaunch bellions sub drinimats ob kuestify sa thespired [eos]': 1,
#  'se sub tarses [eos]': 37,
#  'streck ambather sub filks [eos]': 1,
#  'mespician sub dake ca bunessator ca yeige rattiners sub stroveda rel stourts ob rawn sa sergatized [eos]': 1,
#  'crene fossicians sub miticurize [eos]': 1,
#  'frominalist sub pi ob bolicized [eos]': 1,
#  'threak fremators sub sherician ob saultify sa fanches rel frominalist sub amackates [eos]': 1,
#  'me sub framitatores [eos]': 38,
#  'si sub bo sub me sub rawns sa crailed sa thespired rel eluper ob lavoidifieda [eos]': 1,
#  'si sub rolveda [eos]': 150,
#  'shrop benatician sub jeethe crotifers ob mespicated sa mangere rel duskists sub lustodist ob jeapeda [eos]': 1,
#  'yeige stimper sub ja ob frains [eos]': 1,
#  'meech wuthers ob irriticiateda rel fumitists sub mue [eos]': 1,
#  'noachers sub framitator sub mued sa thespire [eos]': 1,
#  'framitator sub jont burse ob gratenized [eos]': 1,
#  'pi sub thrope smoob ob praimed [eos]': 1,
#  'ballison sub remiffs [eos]': 2,
#  'froachere rel wanners sub la ob pouteratizeda [eos]': 1,
#  'la sub thrub rel dargines ob phonorize sa fanched rel thullician sub peachician ob phoisifies [eos]': 1,
#  'crene stimpers sub douch shagoner ob phonorize rel gratenists sub streck madetor ob shumpify sa sergatized rel stimper ob enjurify [eos]': 1,
#  'ja sub prither sub striberated sa nobs [eos]': 1,
#  'streachor sub ja ob lawticianed [eos]': 1,
#  'si sub nusts ob enjurify [eos]': 1,
#  'hostist sub se ob poutered [eos]': 1,
#  'si sub penessers ob traiveda [eos]': 1,
#  'me sub remiffed [eos]': 29,
#  'gangerist sub smeshs [eos]': 2,
#  'fusbend drinimats sub excribit [eos]': 1,
# ...
#  'sergs sub thrombicizeda [eos]': 1,
#  'mofusted rel mespician sub se ob penursiferes [eos]': 1,
#  'yeige sergs sub zild stimper ob stroveda [eos]': 1,
#  'ja sub wuthers sub se ob bub sa squailed [eos]': 1,
#  'me sub mues [eos]': 35,
#  'scooth tiraster sub me ob blarps [eos]': 1,
#  'spean streachors sub gringe tiraster sub ja hi gaunch wanners sub mafes sub si sub si ob wandifieda sa thespired rel smoob sub framitatores sa mangereda sa strovokicizeda sa sergatizes sa fancheda [eos]': 1,
#  'pleddist ob phonorized rel ranater sub onstigipates rel lustodist ob dafes [eos]': 1,
#  'naid mofustators sub wuth nust sub spectified sa sergatizeda [eos]': 1,
#  'ghump jobsticators sub thrombicize [eos]': 1,
#  'plessicate rel gloralizers sub la ob saultifieda [eos]': 1,
#  'bo sub lactissists sub frub blope sub gratenizes sa formanateda sa prutifies [eos]': 1,
#  'pi sub phanicizeda rel madetors ob midicated [eos]': 1,
#  'se sub la sub duppifieda rel mofustators sub si sub fumit bolician ob jobsticatore sa conturizeda rel blopes ob midicate sa unseff sa humicianed [eos]': 1,
#  'tiraster ob poutere rel flingerists sub jawp bunessators sub threak appalate ob saultifieda sa sergatize [eos]': 1,
#  'bolitist sub peaserized [eos]': 1,
#  'la ob fallengizes rel jonter sub stremord redullor sub intrinses sa crails [eos]': 1,
#  'bolicater sub si ob gluck rel bolicians sub chorry sa formanated [eos]': 1,
#  'ja sub bolicians sub fusbend trenner sub bo ob madetizes sa squaileda sa lurchified sa conturize rel formantors sub scooth fragion sub elusists ob choze rel bleckmans sub duppist ob phoisify sa kurches sa sergatizeda [eos]': 1,
#  'ja sub crotified [eos]': 34,
#  'phanicized rel dolonician sub si sub skeer thullicians ob irriticiateda sa kurched [eos]': 1,
#  'elupers sub gustists ob conveameda [eos]': 1,
#  'stremord briticists sub skame buestor lu ja ob frematizeda [eos]': 1,
#  'wolarist sub la sub penessers ma la ob phonorizeda rel thullamors ob bottiste sa pactessed [eos]': 1,
#  'fremator sub jawp peachician ob dupressifies [eos]': 1,
#  'threak wainster hi gringe sergator sub si ob enjurifies [eos]': 1,
#  'botigners sub calikate [eos]': 1,
#  'la sub breight autoner sub la ob clums sa sergatizeda [eos]': 1,
#  'tharon gratenist sub prask gloralizers sub briminated rel justator ob baniticated rel justator ob jontifieda sa embarricates [eos]': 1,
#  'breight duppist sub se ob chozed [eos]': 1,
#  'la sub prottize [eos]': 90,
#  'pi sub jurb hilldomer sub si ob croiled sa saunches [eos]': 1,
#  'gringe ecoster sub garfs [eos]': 1,
#  'hild buestors sub jeethe bellion sub la sub mofustateda sa engarified sa unseff [eos]': 1,
#  'la sub spean lenn ob joof [eos]': 1,
#  'prask lactissists ob soskeda rel amackists sub peagerists ob yolve [eos]': 1,
#  'wuth draccont sub visivet sub pi sub bo ob missipates rel purgettor hi se ob rebinked sa unseffed sa strovokicized [eos]': 1,
#  'ja ob rebinkeda rel burses sub rolveda [eos]': 1,
#  'si sub douch gustist ob fallengize [eos]': 1,
#  'framitator sub si ob pleddisates sa engarified rel nust sub nestators sub scuppeda sa crins [eos]': 1,
#  'madetors sub shrop gloralizer ma baniticians ob thafassize sa strovokicizes rel flingerist ca me sub treaves [eos]': 1,
#  'hild briticist sub thrombicizes [eos]': 1,
#  'bo sub greanerizes [eos]': 35,
#  'draccont sub si sub stoppisteda sa engarified [eos]': 1,
#  'wuth croticians sub fantivists sub engarieda sa humicianeda [eos]': 1,
#  'piliciate rel midicians sub striberists ob engarieda [eos]': 1,
#  'trachier sub la ob gumitified [eos]': 1,
#  'ja sub offaldicates [eos]': 42,
#  'yeige fumitists sub phanicizeda [eos]': 1,
#  'elusifies rel prither sub plessicates [eos]': 1,
#  'si sub ralmeda [eos]': 76,
#  'pi sub streachor hi lenns sub meech wainsters ob apturicizeda sa lurchifieda rel briticists ob kippigated [eos]': 1,
#  'skeezed rel businator sub treaved [eos]': 1,
#  'bo sub ja sub plessickes sa formanates [eos]': 1,
#  'jont bullawer hi si da bo ca jobsticator ca naridators sub si ob baniticate [eos]': 1,
#  'briminate rel frominalers sub limbatizeda [eos]': 1,
#  'gringe fusbenders sub maksizeda rel senths ob jobsticatore rel ranaters sub prottize sa humiciane rel haustists sub ghump visivet sub autoner ob praims rel lurchist ob croicerates sa conturizeda sa sergatize rel hilldomers ob zurch [eos]': 1,
#  'se sub si ob chozes [eos]': 3,
#  'botig briticists sub thrombicizeda [eos]': 1,
#  'shrop flingerists sub bo ob dupressifieda [eos]': 1,
#  'bo sub clim povicians sub milturor sub si sub se ob pleddisate rel stimpers ob missipeda sa crinned sa sergatizes rel jobsticator ob mafflitate sa squailed [eos]': 1,
#  'wolarists ob gumitified rel sherician ob spooleda rel jonters ob bactivitated rel businer sub filks [eos]': 1,
#  'thullamors sub pi ma bo ca crene hostists da la sub mofustateda sa embarricate [eos]': 1,
#  'si sub thrubbeda rel purgettors sub burse ob botticate sa nobeda [eos]': 1,
#  'si sub purgett frawkess ob penursifereda [eos]': 1,
#  'bo sub swarmicates [eos]': 25,
#  'bellion sub ralms [eos]': 2,
#  'breight peagerist sub la sub portify sa prutifies [eos]': 1,
#  'wainsters sub crotifieda sa conturizeda rel trenners sub thullamizeda [eos]': 1,
#  'si sub skeezes rel hane sub fumit fossicians ob engaries sa crail [eos]': 1,
#  'la sub breaper ob draireda [eos]': 1,
#  'la sub dorpalist ob apturicizeda sa crinned rel madetor sub lustodist ob pouteratize rel fragions ob dafes [eos]': 1,
#  'thrubbed rel justator sub wuth briticists ob pouteratizes [eos]': 1,
#  'tiraster sub spean gezziman sub chorries sa fanched rel amackist ob dafes [eos]': 1,
#  'thrope hilldomer sub maksizes [eos]': 1,
#  'scooth amationists ob thafassized rel shagoner sub intrinsed [eos]': 1,
#  'si ob dismaffe rel formantors sub phanicizeda rel peachicians ob pipistrateda [eos]': 1,
#  'scooth thullamor sub la ob gratene rel bunessators ob bottisted [eos]': 1,
#  'zild hostician sub garfs [eos]': 1,
#  'ja sub bilth madetors ob enjurify rel botigners sub se sub bilth guendors ob bubs sa craileda sa crin rel voncenists ob garfed [eos]': 1,
#  'jont framitators sub wuth stimper sub denaticated sa engarifieda rel narters ob dismaffeda sa humicianeda rel shericians sub la ob spool [eos]': 1,
#  'ecoster sub visified [eos]': 2,
#  'skame midicians sub skeeze rel dakes ob phoisify [eos]': 1,
#  'osmissifieda rel amackists sub croticians sub garf sa crinneda [eos]': 1,
#  'engary rel redullors sub bunessiste [eos]': 1,
#  'jont kewardessor sub la sub dorpal ob ninged rel elusist sub apturicizeda rel ballisons ob scolterizeda rel haustists sub unpleweda sa sauncheda rel shagoners sub jawp tharoners sub calin drousemans ob gratenizeda sa humicianeda sa conturizes sa pactesseda sa mangeres [eos]': 1,
#  'si sub tismissate [eos]': 88,
#  'drousemans sub la sub skeer pleddist sub denatician sub gloralizer sub broals sa kurches sa sedundifies sa kurche sa fancheda [eos]': 1,
#  'plonth wanner ob duppifieda rel jonters sub me sub rolves sa sergatize [eos]': 1,
#  'bo sub la ca strogessors ob baniticated [eos]': 1,
#  'blide smoobs sub calin fragion sub formantor sub mofustated sa mangeres sa engarifieda [eos]': 1,
#  'si sub jurb pleddists sub darsh fremator sub clim autoner sub unplewed sa crins rel burse ob stickerates sa prutified rel nust sub guend dracconts sub dreek wotankers ob apturicizeda sa nobs sa saunch sa conturizeda [eos]': 1,
#  'stourt sub scupped [eos]': 3,
#  'duskist sub offalded [eos]': 1,
#  'botig flingerist sub maksizeda rel strogessors ob bunessistes [eos]': 1,
#  'guend flingerist sub jont kuestors ob rawned rel penursifer sub flingericians ob slurked sa sedundified [eos]': 1,
#  'jurb flingericians sub me sub kewardessors sub ghump milturor sub droinists ob dupressed sa formanate sa embarricates sa fancheda [eos]': 1,
#  'crene ampercial sub portified [eos]': 1,
#  'se sub si sub greanerize sa sergatizes [eos]': 1,
#  'si sub osmissifieda [eos]': 89,
#  'la ma scoaned rel stimper sub draccont sub gaunch predignor ob garfed rel voncenist sub drinimat sub hurperated sa embarricated sa crinned sa lurchifies [eos]': 1,
#  'phanicizes rel stremorder ma me sub hild streachor sub limbatizes sa saunched [eos]': 1,
#  'jont fremators sub me sub thullamors sub dreek autoners sub botig froachers ob bunessisteda sa engarifieda sa sedundifies sa prutify [eos]': 1,
#  'damerticates rel tib sub teeves sa sedundifies rel crotifer sub sturks sa fanches rel bullif sub frub hostists ob likiciates [eos]': 1,
#  'ja sub mattakates [eos]': 31,
#  'purgett lenns hi la sub dargine ob disfrinse [eos]': 1,
#  'crene voncenists sub si sub peachiciane sa strovokicizeda [eos]': 1,
#  'piliciated rel drouseman sub pi sub skame striberists sub shrop da meech purgettor sub la ob likiciates sa pactess sa saunch rel shericians sub dupp sa mangered sa unseffed [eos]': 1,
#  'se sub si ob annoriciates [eos]': 2,
#  'fusbenders sub portify [eos]': 2,
#  'scooth protter sub purgettor ob stickerates [eos]': 1,
#  'bunessators sub la ob strubdify [eos]': 1,
#  'benaticians sub limbatize sa strovokicizes rel kewardessor sub bolician sub bo ob chozed sa conturizes [eos]': 1,
#  'scooth cushars sub stoppiste [eos]': 1,
#  'appalate sub penursifers sub amackateda sa strovokicized sa crailed rel frawkess sub revalternated [eos]': 1,
#  'predignor ob blamiciate rel horriers sub moldician sub charch rel stimpers ob povicates sa nobeda [eos]': 1,
#  'fremators sub spean bolitists sub intrinse sa sergatized rel bunessator sub prithers sub naid rattiners sub breight sherician sub penessers sub me ob frain sa conturizes rel senth sub pi sub peagerizes sa saunch rel purgettors sub peagerize sa crins sa pactessed sa unseff sa formanateda sa lurchified sa pactess [eos]': 1,
#  'pouteres rel bellion sub mofustates [eos]': 1,
#  'la sub briticist sub remiffs rel denatician sub ballicize rel pactesses ob frematized sa engarified sa nob [eos]': 1,
#  'wainster ob gratenes rel amackist sub crotifer ob zurched sa formanate rel povicians sub fantivists sub teeveda rel nestators sub serd ob spooleda sa prutify sa embarricateda [eos]': 1,
#  'thrope lenns sub intrinseda [eos]': 1,
#  'prausifieda rel ricatites sub ralmeda [eos]': 1,
#  'plonth ricatite sub engaries [eos]': 1,
#  'guend businator ob stoppiste rel tirasters sub calikate [eos]': 1,
#  'la sub rotectify [eos]': 85,
#  'mermillated rel fremator da bilth midician sub swarmicated rel gratenist ob gratene [eos]': 1,
#  'ja sub damerticates [eos]': 33,
#  'si sub wuth visivets ob dafe [eos]': 1,
#  'yeige duppist sub scooth smoobs sub douch noachers sub me sub wandifies sa embarricateda sa saunch sa unseffs [eos]': 1,
#  'jont ecoster sub douch lurchist sub skeer flingerists ob dafed sa fanched sa embarricated rel fumitist sub la sub plonth madetors sub buestor sub la sub zild dolonicians sub peaserize sa mangereda sa prutifies sa formanateda sa engarified rel guendor sub jantomized sa embarricateda sa nobs [eos]': 1,
#  'si sub bo ob lustodiste [eos]': 5,
#  'la sub se sub amberates sa formanateda rel autoners ob croicerateda [eos]': 1,
#  'la sub saffleda sa kurche rel tibs sub briminateda [eos]': 1,
#  'clim rattiner sub prausifieda rel shericians ob croileda rel dakes ob drols [eos]': 1,
#  'baniticians sub fampenate [eos]': 2,
#  'pi ob strubdifieda rel ranaters hi businers sub ja ob jobsticatore sa lurchifies rel peachician ca la sub jeethe mespician ob dafes rel brelland ob disfrinse sa saunches rel tharoner sub pi sub ja ob phonorizes sa crails [eos]': 1,
#  'fremator sub wolarists sub garfeda sa unseffs [eos]': 1,
#  'peachician ob heferated rel predignor sub tirasted [eos]': 1,
#  'blide bolicians sub naid benaticians ob irriticiateda rel gezzimans sub la ob baniticateda sa strovokicize [eos]': 1,
#  'la sub plonth ricatites ob glucks rel shodderist sub mattakated sa squaileda [eos]': 1,
#  'sergs sub peagerize [eos]': 1,
#  'bolitist ob dafeda rel humicians sub ranater ob midicate [eos]': 1,
#  'fumit dargines sub la hi doloner sub la sub bo sub la ob jobsticatored sa fancheda sa mangered sa sergatize [eos]': 1,
#  'yerg da jurb fusbenders sub bo ob greanerizeda [eos]': 1,
#  'amberates rel stimper sub bo sub la ob yolved sa saunches [eos]': 1,
#  'mofusteda rel drousemans sub peachician sub plessicked sa nobeda rel bunessators ob bub [eos]': 1,
#  'si sub scoaneda [eos]': 95,
#  'gangerist sub piliciates sa bules rel bottist sub jeethe baniticians sub ralm rel stremorders sub mangerize sa embarricate sa crinned [eos]': 1,
#  'bo sub bilth pilobist sub se hi skeer fragion sub duppifies sa unseffs sa prutified [eos]': 1,
#  'businator sub prask fumitists sub ampercial ob yolveda sa sergatizes [eos]': 1,
#  'senths sub pi sub scupps sa humicianeda [eos]': 1,
#  'jawp thullicians sub gustists ob kuestifieda sa bules rel penesser sub gratenizes sa pactess rel melottesses sub naid hules ob chutch [eos]': 1,
#  'ecoster sub poutered [eos]': 3,
#  'revalternates rel rattiner sub revalternate rel bellions sub pi sub calin pactesses ma la ob droled sa kurche sa sedundifies [eos]': 1,
#  'la ca mangerize rel bolicaters sub gratenist sub peagerized sa sergatize sa humicianeda rel thullamors sub gratenizeda rel flingericians ob stoppisteda [eos]': 1,
#  'scoans rel shagoner sub amacked [eos]': 1,
#  'chorry rel midicians ca maksizeda rel fragions sub voncenist sub gringe mafflitists ob garfs sa fancheda [eos]': 1,
#  'si sub fusilitateda [eos]': 86,
#  'stourts ca se sub rotectified [eos]': 1,
#  'ronders sub guend da naid elusists sub rawneda sa crail [eos]': 1,
#  'ja sub fusbenders ob povicated [eos]': 1,
#  'yerg stourt sub jont lactimer ca la da me da si ob bubbed [eos]': 1,
#  'stremord amackist sub mofusted [eos]': 1,
#  'denaticians sub me ob soskeda [eos]': 1,
#  'cheldors sub portifieda [eos]': 4,
#  'fumit haustist sub swarmicates [eos]': 1,
#  'trenner sub osmissifies [eos]': 1,
#  'darsh lactissist sub revalternates rel hostician ob intrinsed [eos]': 1,
#  'yeige dorpals sub engarieda [eos]': 1,
#  'me sub se ob damerticated [eos]': 2,
#  'shrop brellands sub zurcheda [eos]': 1,
#  'smoobs sub bo sub me sub la ob wandifies sa conturized rel hostist lu la lu prask voncenist hi si ob mafflicates sa sedundify [eos]': 1,
#  'si sub si ca pi ob duppifieda [eos]': 1,
#  'bolicaters sub rotectify sa crinned rel drouseman sub engaries [eos]': 1,
#  'shrop frawkesses hi ja sub threak trapenist sub la ca justators ob greanerize rel flingericians sub ja sub yawled sa mangere sa crins sa engarified [eos]': 1,
#  'trenners sub ballicize [eos]': 2,
#  'bo sub fossicians ob praims sa unseff rel fragions sub si sub spean bolitists sub si sub hane ob traiveda sa embarricated rel ecoster ob bolicize sa sergatize sa buleda [eos]': 1,
#  'pi sub rattiners ob joofed [eos]': 1,
#  'dolonician sub saffled [eos]': 2,
#  'guend bactivitor ma blide da clim stoppists sub lactissists da piliciates rel enlator sub scuppeda sa prutifies rel milturor ob blitcheda rel peagerists ob penursifereda [eos]': 1,
#  'se sub doloner sub darsh fremators ob frematize rel businators ob theslirated sa squails [eos]': 1,
#  'spean burse sub parls [eos]': 1,
#  'pi sub si sub darsh guendors ob penursifere sa strovokicizes sa prutifieda rel bleckmans sub elupizeda [eos]': 1,
#  'scooth gloralizers sub dreek dakes ob croileda [eos]': 1,
#  'ricatites sub trenner sub maksizeda rel formantors sub skeezeda rel ambathers ob jontifieda sa crinned sa sedundifieda [eos]': 1,
#  'fumit nust sub osmissifies [eos]': 1,
#  'dakes sub breight wanner hi bo ob kippigateda [eos]': 1,
#  'frominaler sub vems [eos]': 3,
#  'benaticianeda rel hanes sub la sub kewardessor ob scolterize sa sedundify [eos]': 1,
#  'skeer mofustator sub serds ob annoriciateda rel wanners sub mermillateda sa strovokicized [eos]': 1,
#  'yeige jobsticator sub ralms [eos]': 1,
#  'dreek serds sub maksize [eos]': 1,
#  'drinimat sub hane sub si sub scooth penursifers ob baniticated rel bolitist sub melottess sub teeved sa formanated sa buleda rel ranaters ob midicateda sa humicianes sa engarifies [eos]': 1,
#  'hanes sub calikate sa engarifieda rel tharoners sub si sub briticist ob intrinse sa thespireda [eos]': 1,
#  'jont kuestor sub si ob thafassized rel noacher sub forigates sa squailed [eos]': 1,
#  ...}
